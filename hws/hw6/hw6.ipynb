# %% [markdown]
# <a href="https://colab.research.google.com/github/326-YL/403-Fall-2022/blob/main/hws/hw6/hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 6 Dynamics Simulation

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import math 
import time 
import seaborn as sns
from matplotlib import animation
from IPython.display import HTML
# %matplotlib inline

# %% [markdown]
# # Q.1 **Ball Bouncing Simulation**
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/bouncing_ball.png?raw=true" width="400">
#
# ## **Q.1 (a) [10pts] Make a simulation of the a bouncing ball with the following characterstics.**
# \begin{align}
# m &=1kg, p_0=(0, 1.5), v_0=(0.3, -0.1), \gamma=0.8,
# \end{align}
# where $\gamma$ is the coefficient of resititution of the ball. use $\Delta t=0.001$ sec and simulate the bouncing ball during 3 sec. (Note: No frictional loss)

# %%
def simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N=3000):
  g = -9.8
  p_hist = np.zeros((N, 2))
  #print(p_hist)
  v_hist = np.zeros((N, 2))
  #print(v_hist)
  t_hist = np.zeros(N)
  p_hist[0, :] = init_pos
  print(p_hist[0])
  v_hist[0, :] = init_vel
  #print(v_hist)
  for i in range(1, N):
      # Fill your code: Add velocity update with acceleration
      #print(f"velocity is {v_hist[i-1:]}")
      v_hist[i,1]=v_hist[i-1,1]+g*delta_t
      v_hist[i,0]=init_vel[0]
      if p_hist[i-1, 1]<=0 and v_hist[i, 1]<0:
         # Fill your code: Sudden velocity change when the ball hits the ground
         v_hist[i,1]=-coeff_rest*v_hist[i-1,1]          

      # Fill your code: Update ball position
      p_hist[i,1]=p_hist[i-1,1]+v_hist[i,1]*delta_t
      #print(v_hist[0,0])
      p_hist[i,0]=p_hist[i-1,0]+v_hist[i,0]*delta_t
      #print(p_hist[i,0])
      t_hist[i:] = i*delta_t;
  print(v_hist)
  return p_hist, v_hist, t_hist

# %%
g = -9.8
N = 3000

# Fill your code: set up proper parameters and initial state to call the 'simulate_ball' function
mass =1
init_pos =np.array([0,1.5])  # x, y
init_vel =np.array([0.3,-0.1])  # x_vel, y_vel
coeff_rest =0.8 
delta_t = 0.001
[p_hist, v_hist, t_hist] = simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N)
# Out:
# [0.  1.5]
# [[ 0.3        -0.1       ]
#  [ 0.3        -0.1098    ]
#  [ 0.3        -0.1196    ]
#  ...
#  [ 0.3        -0.63496544]
#  [ 0.3        -0.64476544]
#  [ 0.3        -0.65456544]]

# %%
# Bouncing ball visualization: No need to change
def plot_bouncingball(p_history, t_history, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  wall1, = ax.plot([-2, 2], [0, 0], 'b', lw=1)          
  ball, = ax.plot([0], [0], 'ro', markersize=12)     
  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -1.5, 1.5))            
  ax.set_ylim((-0.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(p_history)//num_frames
  def drawFrame(k):
    k = interval*k
    p0 = p_history[k]

    ball.set_data([p0[0]], [p0[1]])
    txt_title.set_text('t = {:.2f} sec'.format(t_history[k]))
    return ball,
  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
anim = plot_bouncingball(p_hist, t_hist, num_frames= 100)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
plt.plot(p_hist[:, 0], p_hist[:, 1])
plt.show()

# %% [markdown]
# ##Q.1(b) [5 pts] **What is the position and velocity of the ball after 2 sec ?**

# %%
# Fill your code: Print the position and velocity at 2 sec
print(f"pos:{p_hist[2000]}, vel: {v_hist[2000]}")
# Out:
# pos:[0.6       0.3846555], vel: [ 0.3      -2.117296]

# %% [markdown]
# ##Q.1(c) [10 pts] **What is the position and velocity of the ball after 2 sec when you use $\Delta_t=0.01$? Explain why the values are different from the result of (a). Put your answers in the following text box.**

# %%
# Fill your code: Simulate the bouncing ball again with new delta t
delta_t_2 = 0.01
[p_hist_2, v_hist_2, t_hist_2] =simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N)
print(p_hist_2[100])
# Fill your code: Print the position and velocity at 1 sec
#1 sec or 2 sec and result different
print(f"pos: {p_hist_2[200]}, vel: {v_hist_2[200]}")
# Out:
# [0.  1.5]
# [[ 0.3        -0.1       ]
#  [ 0.3        -0.1098    ]
#  [ 0.3        -0.1196    ]
#  ...
#  [ 0.3        -0.63496544]
#  [ 0.3        -0.64476544]
#  [ 0.3        -0.65456544]]
# [0.03    1.44051]
# pos: [0.06    1.28302], vel: [ 0.3  -2.06]

# %%
plt.plot(p_hist_2[:, 0], p_hist_2[:, 1])
plt.plot(p_hist[:, 0], p_hist[:, 1])
plt.show()

# %% [markdown]
# ## Q.1 (c) Put your explanation here:
#
# ---since the delta_t increases, the change of velocity_y in new delta_t is smaller than the old value, that means the new velocity in the same amount of time units (2 sec) is decreased, when the velocity_y decreases, the position_y decreases as well
#
#
#
# ---

# %% [markdown]
# # Q.2 **Pinball Simulation**
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/pinball.png?raw=true" width="500">

# %% [markdown]
# ## Q.2 [20 pts] (a) Simulate the pin ball motion. Assume the radius of the ball is approximately zero and no frictional loss. Use coefficient of restitution, $\gamma$ = 0.9, initial pos: [0.5, 1.0], and initial velocity: [1.5, 0.5]. Simulate over 5 sec.

# %%
# Collision checking code: No need to change
def point_line_distance(point, line):
  distance = np.linalg.norm(np.cross(line[0]-point, line[1]-point))/np.linalg.norm(line[1]-line[0])
  return distance 

def detect_collsion(pos, walls, threshold=0.001):
  dlist = []
  collision_idx = None
  for i, wall in enumerate(walls):
    d = point_line_distance(pos, wall)
    dlist.append(d)
    if d<=threshold:
      collision_idx = i
  return collision_idx

# %%
# Simulate Pinball
def simulate_pinball(coeff_rest, init_pos, init_vel, delta_t, walls, wall_norms, wall_tan, N=3000):
  p_hist = np.zeros((N, 2))
  v_hist = np.zeros((N, 2))
  t_hist = np.zeros(N)

  p_hist[0, :] = init_pos
  v_hist[0, :] = init_vel
  t_hist[0] = 0
  for i in range(1, N):
      v_hist[i, :] = v_hist[i-1, :];
      p_hist[i,:]=p_hist[i-1,:]+v_hist[i-1,:]*delta_t
      # Fill your code: Check collision and update velocity
      wall_index=detect_collsion(p_hist[i,:],walls)
      if  wall_index is not None and np.dot(v_hist[i],wall_norms[wall_index])<0:
          #print(wall_index)
          #print(f"dot product is{np.dot(v_hist[i-1,:],wall_norms[wall_index])}")
          #print(f"index:{wall_norms[wall_index]}")
          #print(np.dot(v_hist[i-1,:],wall_norms[wall_index])*np.array(wall_norms[wall_index]))
          v_norm=(np.dot(v_hist[i,:],wall_norms[wall_index])*np.array(wall_norms[wall_index])*(-coeff_rest))
          #print(f"v_norm here:{v_norm}")
          v_tan=np.dot(v_hist[i,:],wall_tan[wall_index])*np.array(wall_tan[wall_index])
          v_hist[i,:]=v_norm+v_tan
      t_hist[i] = i*delta_t    
  return p_hist, v_hist, t_hist

# %%
# Wall definition code: No need to change
wall1 = np.array([[0, 0], [0, 2]])
wall1_norm = [1, 0]
wall1_tan = [0, 1]

wall2 = np.array([[0, 2], [1, 2]])
wall2_norm = [0, -1]
wall2_tan = [1, 0]


wall3 = np.array([[1, 2], [1, 1]])
wall3_norm = [-1, 0]
wall3_tan = [0, 1]

wall4 = np.array([[1, 1], [0, 0]])
wall4_norm = [-1/np.sqrt(2), 1/np.sqrt(2)]
wall4_tan = [1/np.sqrt(2), 1/np.sqrt(2)]

walls = [wall1, wall2, wall3, wall4]
wall_norms = [wall1_norm, wall2_norm, wall3_norm, wall4_norm]
wall_tan = [wall1_tan, wall2_tan, wall3_tan, wall4_tan]

# %%
N_pinball = 5000

# Fill your code: Simulate pinball
dt_pinball =0.001
coeff_rest =0.9

init_pos =[0.5, 1.0]
init_vel =[1.5, 0.5]

[p_hist_pinball, v_hist_pinball, t_hist_pinball] = simulate_pinball(coeff_rest, init_pos, init_vel, dt_pinball, walls, wall_norms, wall_tan, N_pinball)

# %%
# Visualize Pinball Matplotlib: No need to change
def plot_pinball(q, ts, walls, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  # m, c, l, g, mu, dt = params
  wall1, = ax.plot([walls[0][0][0], walls[0][1][0]], [walls[0][0][1], walls[0][1][1]], 'b', lw=1)     
  wall2, = ax.plot([walls[1][0][0], walls[1][1][0]], [walls[1][0][1], walls[1][1][1]], 'b', lw=1)     
  wall3, = ax.plot([walls[2][0][0], walls[2][1][0]], [walls[2][0][1], walls[2][1][1]], 'b', lw=1)     
  wall4, = ax.plot([walls[3][0][0], walls[3][1][0]], [walls[3][0][1], walls[3][1][1]], 'b', lw=1)     
  ball, = ax.plot([0], [0], 'ro', markersize=12)     
  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -1, 2))            
  ax.set_ylim((-0.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(q)//num_frames
  def drawFrame(k):
    k = interval*k
    q0 = q[k]
    ball.set_data([q0[0]], [q0[1]])
    txt_title.set_text('t = {:.2f} sec'.format(ts[k]))
    return ball,
  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
anim = plot_pinball(p_hist_pinball, t_hist_pinball, walls, num_frames= 100)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Q.2.(b) [5 pts] **What is the position and velocity of the ball after 1, 2, 3 sec ?**

# %%
# Fill your code: Print the position and velocity of the ball @ 1, 2, 3 sec
print(f"1 sec pos:{p_hist_pinball[1000]},vel:{v_hist_pinball[1000]}")
print(f"2 sec pos:{p_hist_pinball[2000]},vel:{v_hist_pinball[2000]}")
print(f"3 sec pos:{p_hist_pinball[3000]},vel:{v_hist_pinball[3000]}")
# Out:
# 1 sec pos:[0.09905 1.5    ],vel:[-1.35  0.5 ]
# 2 sec pos:[0.8844125 1.99905  ],vel:[-1.0935 -0.45  ]
# 3 sec pos:[0.1898213 1.54905  ],vel:[ 0.98415 -0.45   ]

# %% [markdown]
# ## Q.2.(c) [10 pts] **Plot the kinetic energy of the ball. Based on the plot explain how the ball loses its energy (Note: The pinball's mass is 1 kg)**

# %%
kin_energy = np.zeros(N_pinball)
m=1
# Fill your code: Compute kinetic energy of the ball and plot
for i in range(len(v_hist_pinball)):
   v_actual=np.power(v_hist_pinball[i,0],2)+np.power(v_hist_pinball[i,1],2)
   kin_energy[i]=1/2*v_actual*m
plt.plot(t_hist_pinball, kin_energy)
plt.show()

# %% [markdown]
# # Q.3 Swing Stick
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/SwingArm.png?raw=true" width="500">

# %% [markdown]
# ## Q.3.(a) [20 pts] Implement a swing stick simulation.
# Use parameters, [$m, I, c, l, \mu, dt$] = [1, 0.05, 0.5, 1.0, 0, 0.001].
#
# Simulate the case when [$\theta_0, \dot{\theta}_0$] = [0, 0] and $F$ is applied at the tip of the arm during 0.05 sec to the vertical direction.

# %%
def sim_step(theta, theta_dot, F, tau , params=None):
  m, I, c, l, mu, dt = params
  print("in sim")
  # Fill your code: implement dynamics to compute the angular acceleration
  theta_ddot =(tau+l*np.cos(theta)*F-mu*theta_dot)/(I+np.power(c,2)*m)
  print(theta_ddot)
  # Fill your code: Semi-implciti Euler integration
  th_dot =theta_dot+dt*theta_ddot
  th =theta+dt*th_dot
  print([th,th_dot])
  return [th, th_dot]
  
def simulate_stick(theta=0, theta_dot=0, F=50, tau=0, F_duration=0.05, F_start_time=0.0, T=1.0, params=None):
  dt = params[-1]
  ts = np.linspace(0, T, int(T/dt))
  print(len(ts))
  theta_hist = [theta]
  print(f"theta hist {theta_hist}")
  theta_dot_hist = [theta_dot]
 
  print(f"theta_dot_hist {theta_dot_hist}")
  # Fill your code: Implement the case that the external force pushes the tip of the arm
  tz=0
  for i, t in enumerate(ts):
    print(f"i is {i}")
    #zt=z0+ z0dot *delta_t
    
    if tz==F_start_time:
        print("in zo")
        [theta_hist[i],theta_dot_hist[i]]=[theta,theta_dot]
        print(f"len of his:{len(theta_hist)}")
        print(f"len of dot :{len(theta_dot_hist)}")
    elif tz>F_start_time and tz<=F_duration:
        [th,th_dot]=sim_step(theta_hist[i-1],theta_dot_hist[i-1],F,tau,params=params)
        print(f"th:{th}")
        print(theta_dot_hist[i-1])
        a=theta_hist[i-1]
        z=a+th
        b=theta_dot_hist[i-1]
        z_dot=b+th_dot
        theta_hist.append(z)
        theta_dot_hist.append(z_dot)
        #print(sim_step(theta_hist[i-1],theta_dot_hist[i-1],F,tau,params=params))
        #print(f"his is:{theta_hist[i-1]}")
        #theta_hist[i+1]=theta_dot_hist[i]+z_dot_dt[0]
        #theta_dot_hist[i+1]=theta_dot_hist+z_dot_dt[1]
        #[theta_hist[i+1],theta_dot_hist[i+1]]=np.array([theta_hist[i],theta_dot_hist[i]])+z_dot_dt
    if tz==F_duration:
        break;
    tz=tz+dt 
  ts = ts.tolist()
  ts.append(T)
  return [theta_hist, theta_dot_hist, ts]

# %%
# Visualization code: Do not need to change
def plot_stick(q, ts, params, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  m, I, c, l, mu, dt = params
  link1, = ax.plot([], [], 'b', lw=10)     # ax.plot returns a list of 2D line objects  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -2.5, 2.5))    # Canvas size        
  ax.set_ylim((-2.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(q)//num_frames

  def drawFrame(k):
    k = interval*k
    q0 = q[k]
    rA = [l*np.cos(q0), l*np.sin(q0)]
    x1 = 0
    x2 = rA[0]
    y1 = 0
    y2 = rA[1]
    link1.set_data([x1, x2], [y1, y2])
    txt_title.set_text('t = {:.2f} sec'.format(ts[k]))
    return link1,

  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
# Let's use param: [mass, Inertia, CoM, length, friction coefficient, delta_t]
# Fill your code: Run simulation
params=[1, 0.05, 0.5, 1.0, 0, 0.001]
[theta_hist, theta_dot_hist, ts] =simulate_stick(theta=0, theta_dot=0, F=50, tau=0, F_duration=0.05, F_start_time=0.0, T=1.0,params=params)
# Out:
# 1000
# theta hist [0]
# theta_dot_hist [0]
# i is 0
# in zo
# len of his:1
# len of dot :1
# i is 1
# in sim
# 166.66666666666669
# [0.0001666666666666667, 0.16666666666666669]
# th:0.0001666666666666667
# 0
# i is 2
# in sim
# 166.6666643518519
# [0.0004999999976851852, 0.3333333310185186]
# th:0.0004999999976851852
# 0.16666666666666669
# i is 3
# in sim
# 166.66662962963127
# [0.0013333332916666686, 0.6666666273148165]
# th:0.0013333332916666686
# 0.49999999768518527
# i is 4
# in sim
# 166.6663333334591
# [0.0033333329143519813, 1.3333329583334608]
# th:0.0033333329143519813
# 1.1666666250000017
# i is 5
# in sim
# 166.66429630232648
# [0.00799999675000629, 2.666663879635789]
# th:0.00799999675000629
# 2.4999995833334623
# i is 6
# in sim
# 166.65185207958007
# [0.018666644935425625, 5.333315315048831]
# th:0.018666644935425625
# 5.166663462969251
# i is 7
# in sim
# 166.58134075054176
# [0.042666534674571044, 10.666560118768624]
# th:0.042666534674571044
# 10.499978778018082
# i is 8
# in sim
# 166.20229183762814
# [0.09599925041899779, 21.332741188624333]
# th:0.09599925041899779
# 21.166538896786705
# i is 9
# in sim
# 164.24531895220233
# [0.2133292850537345, 42.66352540436324]
# th:0.2133292850537345
# 42.49928008541104
# i is 10
# in sim
# 154.52923079171845
# [0.46931237942367177, 85.31733472056601]
# th:0.46931237942367177
# 85.16280548977429
# i is 11
# in sim
# 109.58245628080228
# [1.0238971467933986, 170.5897226666211]
# th:1.0238971467933986
# 170.4801402103403
# i is 12
# in sim
# -50.27268772821155
# [2.218224161109409, 341.01959018923316]
# th:2.218224161109409
# 341.0698628769614
# i is 13
# in sim
# -96.42641526055966
# [4.77742175868052, 681.993026650934]
# th:4.77742175868052
# 682.0894530661946
# i is 14
# in sim
# -141.91924584589142
# [10.236791051181388, 1363.9405604712827]
# th:10.236791051181388
# 1364.0824797171285
# i is 15
# in sim
# 161.06132721079652
# [21.837825643407115, 2728.184101515622]
# th:21.837825643407115
# 2728.023040188411
# i is 16
# in sim
# -165.71771257666452
# [46.403508609290064, 5456.041423991457]
# th:46.403508609290064
# 5456.207141704033
# i is 17
# in sim
# 136.2616220017538
# [98.26336062190616, 10912.384827317492]
# th:98.26336062190616
# 10912.24856569549
# i is 18
# in sim
# -161.04913826493313
# [207.43880876036957, 21824.47234387472]
# th:207.43880876036957
# 21824.633393012984
# i is 19
# in sim
# -156.32860059246266
# [436.70209458515154, 43648.94940828712]
# th:436.70209458515154
# 43649.10573688771
# i is 20
# in sim
# 155.09807782752236
# [917.0534500052686, 87298.21024325264]
# th:917.0534500052686
# 87298.05514517482
# i is 21
# in sim
# 166.09050093573228
# [1921.405121246213, 174596.43147892843]
# th:1921.405121246213
# 174596.26538842748
# i is 22
# in sim
# 65.57602460090004
# [4017.406573456878, 349192.7624433805]
# th:4017.406573456878
# 349192.6968673559
# i is 23
# in sim
# 47.02629685880395
# [8384.00589080741, 698385.5063370332]
# th:8384.00589080741
# 698385.4593107364
# i is 24
# in sim
# -154.78657668125837
# [17466.39708613898, 1396770.8108611929]
# th:17466.39708613898
# 1396770.9656477696
# i is 25
# in sim
# -147.96958066542686
# [36329.56498995615, 2793541.628539382]
# th:36329.56498995615
# 2793541.7765089627
# i is 26
# in sim
# -159.67525893008477
# [75452.671596746, 5587083.245373085]
# th:75452.671596746
# 5587083.405048344
# i is 27
# in sim
# 121.92954927072662
# [156492.42672046993, 11174166.772350978]
# th:156492.42672046993
# 11174166.65042143
# i is 28
# in sim
# -86.93905860560503
# [324159.02000442223, 22348333.33583335]
# th:324159.02000442223
# 22348333.422772408
# i is 29
# in sim
# 77.48550677685122
# [670666.3735091025, 44696666.836091265]
# th:670666.3735091025
# 44696666.758605756
# i is 30
# in sim
# 161.0185981988786
# [1386029.4139378292, 89393333.75571562]
# th:1386029.4139378292
# 89393333.59469703
# i is 31
# in sim
# -164.45637753630064
# [2861452.1613058993, 178786667.1859563]
# th:2861452.1613058993
# 178786667.35041267
# i is 32
# i is 876
# i is 877
# i is 878
# i is 879
# i is 880
# i is 881
# i is 882
# i is 883
# i is 884
# i is 885
# i is 886
# i is 887
# i is 888
# i is 889
# i is 890
# i is 891
# i is 892
# i is 893
# i is 894
# i is 895
# i is 896
# i is 897
# i is 898
# i is 899
# i is 900
# i is 901
# i is 902
# i is 903
# i is 904
# i is 905
# i is 906
# i is 907
# i is 908
# i is 909
# i is 910
# i is 911
# i is 912
# i is 913
# i is 914
# i is 915
# i is 916
# i is 917
# i is 918
# i is 919
# i is 920
# i is 921
# i is 922
# i is 923
# i is 924
# i is 925
# i is 926
# i is 927
# i is 928
# i is 929
# i is 930
# i is 931
# i is 932
# i is 933
# i is 934
# i is 935
# i is 936
# i is 937
# i is 938
# i is 939
# i is 940
# i is 941
# i is 942
# i is 943
# i is 944
# i is 945
# i is 946
# i is 947
# i is 948
# i is 949
# i is 950
# i is 951
# i is 952
# i is 953
# i is 954
# i is 955
# i is 956
# i is 957
# i is 958
# i is 959
# i is 960
# i is 961
# i is 962
# i is 963
# i is 964
# i is 965
# i is 966
# i is 967
# i is 968
# i is 969
# i is 970
# i is 971
# i is 972
# i is 973
# i is 974
# i is 975
# i is 976
# i is 977
# i is 978
# i is 979
# i is 980
# i is 981
# i is 982
# i is 983
# i is 984
# i is 985
# i is 986
# i is 987
# i is 988
# i is 989
# i is 990
# i is 991
# i is 992
# i is 993
# i is 994
# i is 995
# i is 996
# i is 997
# i is 998
# i is 999

# %%
anim = plot_stick(theta_hist, ts, params)
plt.close()
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-155-ab9eb691c328> in <module>
#       1 anim = plot_stick(theta_hist, ts, params)
#       2 plt.close()
# ----> 3 HTML(anim.to_html5_video())
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1329                 writer = Writer(codec='h264',
#    1330                                 bitrate=rcParams['animation.bitrate'],
# -> 1331                                 fps=1000. / self._interval)
#    1332                 self.save(str(path), writer=writer)
#    1333                 # Now open and base64 encode.
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## Q.3.(b) [5 pts] What is the angular position and velocity after 0.5, 1.0, 1.5 sec?

# %%
# Fill your code: Print the angular position and velocity of the arm @ 1, 2, 3 sec
...
# Out:
# 1 sec pos: 0.3962334159211724, vel: 0.8332971897656587
# 2 sec pos: 0.8128820108040016, vel: 0.8332971897656587
# 3 sec pos: 1.2295306056868613, vel: 0.8332971897656587

# %% [markdown]
# ## Q.3. (c) [15 pts] Compute the torque to hold the position of the stick when $F = 50$N at the three following position ($\dot{\theta} = 0$)
# ### (i) $\theta=0$, $\theta=\frac{\pi}{4}$, and $\theta=\frac{\pi}{6}$
# ### (ii) Simulate the robot at the configuration in (i) and check whether the stick moves or not.

# %%
_, _, _, l, _, _ = params

# Fill your code: Compute the torque to hold the motion of the arm
...
# Out:
# Torque: -50.00 Nm
# Torque: -35.36 Nm
# Torque: -43.30 Nm

# %%
# Test your torque: The arm should not move
[theta_hist, theta_dot_hist, ts] = simulate_stick(theta=theta, theta_dot=0, F=50, tau=tau, F_duration=1.0, F_start_time=0.0, T=1.0, params=params)
anim = plot_stick(theta_hist, ts, params)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
