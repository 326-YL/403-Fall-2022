# %% [markdown]
# <a href="https://colab.research.google.com/github/326-YL/403-Fall-2022/blob/main/hws/hw6/hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 6 Dynamics Simulation

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import math 
import time 
import seaborn as sns
from matplotlib import animation
from IPython.display import HTML
# %matplotlib inline

# %% [markdown]
# # Q.1 **Ball Bouncing Simulation**
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/bouncing_ball.png?raw=true" width="400">
#
# ## **Q.1 (a) [10pts] Make a simulation of the a bouncing ball with the following characterstics.**
# \begin{align}
# m &=1kg, p_0=(0, 1.5), v_0=(0.3, -0.1), \gamma=0.8,
# \end{align}
# where $\gamma$ is the coefficient of resititution of the ball. use $\Delta t=0.001$ sec and simulate the bouncing ball during 3 sec. (Note: No frictional loss)

# %%
def simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N=3000):
  g = -9.8
  p_hist = np.zeros((N, 2))
  #print(p_hist)
  v_hist = np.zeros((N, 2))
  #print(v_hist)
  t_hist = np.zeros(N)
  p_hist[0, :] = init_pos
  print(p_hist[0])
  v_hist[0, :] = init_vel
  #print(v_hist)
  for i in range(1, N):
      # Fill your code: Add velocity update with acceleration
      #print(f"velocity is {v_hist[i-1:]}")
      v_hist[i,1]=v_hist[i-1,1]+g*delta_t
      v_hist[i,0]=init_vel[0]
      if p_hist[i-1, 1]<=0 and v_hist[i, 1]<0:
         # Fill your code: Sudden velocity change when the ball hits the ground
         v_hist[i,1]=-coeff_rest*v_hist[i-1,1]          

      # Fill your code: Update ball position
      p_hist[i,1]=p_hist[i-1,1]+v_hist[i,1]*delta_t
      #print(v_hist[0,0])
      p_hist[i,0]=p_hist[i-1,0]+v_hist[i,0]*delta_t
      #print(p_hist[i,0])
      t_hist[i:] = i*delta_t;
  print(v_hist)
  return p_hist, v_hist, t_hist

# %%
g = -9.8
N = 3000

# Fill your code: set up proper parameters and initial state to call the 'simulate_ball' function
mass =1
init_pos =np.array([0,1.5])  # x, y
init_vel =np.array([0.3,-0.1])  # x_vel, y_vel
coeff_rest =0.8 
delta_t = 0.001
[p_hist, v_hist, t_hist] = simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N)
# Out:
# [0.  1.5]
# [[ 0.3        -0.1       ]
#  [ 0.3        -0.1098    ]
#  [ 0.3        -0.1196    ]
#  ...
#  [ 0.3        -0.63496544]
#  [ 0.3        -0.64476544]
#  [ 0.3        -0.65456544]]

# %%
# Bouncing ball visualization: No need to change
def plot_bouncingball(p_history, t_history, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  wall1, = ax.plot([-2, 2], [0, 0], 'b', lw=1)          
  ball, = ax.plot([0], [0], 'ro', markersize=12)     
  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -1.5, 1.5))            
  ax.set_ylim((-0.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(p_history)//num_frames
  def drawFrame(k):
    k = interval*k
    p0 = p_history[k]

    ball.set_data([p0[0]], [p0[1]])
    txt_title.set_text('t = {:.2f} sec'.format(t_history[k]))
    return ball,
  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
anim = plot_bouncingball(p_hist, t_hist, num_frames= 100)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
plt.plot(p_hist[:, 0], p_hist[:, 1])
plt.show()

# %% [markdown]
# ##Q.1(b) [5 pts] **What is the position and velocity of the ball after 2 sec ?**

# %%
# Fill your code: Print the position and velocity at 2 sec
print(f"pos:{p_hist[2000]}, vel: {v_hist[2000]}")
# Out:
# pos:[0.6       0.3846555], vel: [ 0.3      -2.117296]

# %% [markdown]
# ##Q.1(c) [10 pts] **What is the position and velocity of the ball after 2 sec when you use $\Delta_t=0.01$? Explain why the values are different from the result of (a). Put your answers in the following text box.**

# %%
# Fill your code: Simulate the bouncing ball again with new delta t
delta_t_2 = 0.01
[p_hist_2, v_hist_2, t_hist_2] =simulate_ball(mass, coeff_rest, init_pos, init_vel, delta_t, N)
print(p_hist_2[100])
# Fill your code: Print the position and velocity at 1 sec
#1 sec or 2 sec and result different
print(f"pos: {p_hist_2[200]}, vel: {v_hist_2[200]}")
# Out:
# [0.  1.5]
# [[ 0.3        -0.1       ]
#  [ 0.3        -0.1098    ]
#  [ 0.3        -0.1196    ]
#  ...
#  [ 0.3        -0.63496544]
#  [ 0.3        -0.64476544]
#  [ 0.3        -0.65456544]]
# [0.03    1.44051]
# pos: [0.06    1.28302], vel: [ 0.3  -2.06]

# %%
plt.plot(p_hist_2[:, 0], p_hist_2[:, 1])
plt.plot(p_hist[:, 0], p_hist[:, 1])
plt.show()

# %% [markdown]
# ## Q.1 (c) Put your explanation here:
#
# ---since the delta_t increases, the change of velocity_y in new delta_t is smaller than the old value, that means the new velocity in the same amount of time units (2 sec) is decreased, when the velocity_y decreases, the position_y decreases as well
#
#
#
# ---

# %% [markdown]
# # Q.2 **Pinball Simulation**
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/pinball.png?raw=true" width="500">

# %% [markdown]
# ## Q.2 [20 pts] (a) Simulate the pin ball motion. Assume the radius of the ball is approximately zero and no frictional loss. Use coefficient of restitution, $\gamma$ = 0.9, initial pos: [0.5, 1.0], and initial velocity: [1.5, 0.5]. Simulate over 5 sec.

# %%
# Collision checking code: No need to change
def point_line_distance(point, line):
  distance = np.linalg.norm(np.cross(line[0]-point, line[1]-point))/np.linalg.norm(line[1]-line[0])
  return distance 

def detect_collsion(pos, walls, threshold=0.001):
  dlist = []
  collision_idx = None
  for i, wall in enumerate(walls):
    d = point_line_distance(pos, wall)
    dlist.append(d)
    if d<=threshold:
      collision_idx = i
  return collision_idx

# %%
# Simulate Pinball
def simulate_pinball(coeff_rest, init_pos, init_vel, delta_t, walls, wall_norms, wall_tan, N=3000):
  p_hist = np.zeros((N, 2))
  v_hist = np.zeros((N, 2))
  t_hist = np.zeros(N)

  p_hist[0, :] = init_pos
  v_hist[0, :] = init_vel
  t_hist[0] = 0
  for i in range(1, N):
      v_hist[i, :] = v_hist[i-1, :];
      p_hist[i,:]=p_hist[i-1,:]+v_hist[i-1,:]*delta_t
      # Fill your code: Check collision and update velocity
      wall_index=detect_collsion(p_hist[i,:],walls)
      if  wall_index is not None and np.dot(v_hist[i],wall_norms[wall_index])<0:
          #print(wall_index)
          #print(f"dot product is{np.dot(v_hist[i-1,:],wall_norms[wall_index])}")
          #print(f"index:{wall_norms[wall_index]}")
          #print(np.dot(v_hist[i-1,:],wall_norms[wall_index])*np.array(wall_norms[wall_index]))
          v_norm=(np.dot(v_hist[i,:],wall_norms[wall_index])*np.array(wall_norms[wall_index])*(-coeff_rest))
          #print(f"v_norm here:{v_norm}")
          v_tan=np.dot(v_hist[i,:],wall_tan[wall_index])*np.array(wall_tan[wall_index])
          v_hist[i,:]=v_norm+v_tan
      t_hist[i] = i*delta_t    
  return p_hist, v_hist, t_hist

# %%
# Wall definition code: No need to change
wall1 = np.array([[0, 0], [0, 2]])
wall1_norm = [1, 0]
wall1_tan = [0, 1]

wall2 = np.array([[0, 2], [1, 2]])
wall2_norm = [0, -1]
wall2_tan = [1, 0]


wall3 = np.array([[1, 2], [1, 1]])
wall3_norm = [-1, 0]
wall3_tan = [0, 1]

wall4 = np.array([[1, 1], [0, 0]])
wall4_norm = [-1/np.sqrt(2), 1/np.sqrt(2)]
wall4_tan = [1/np.sqrt(2), 1/np.sqrt(2)]

walls = [wall1, wall2, wall3, wall4]
wall_norms = [wall1_norm, wall2_norm, wall3_norm, wall4_norm]
wall_tan = [wall1_tan, wall2_tan, wall3_tan, wall4_tan]

# %%
N_pinball = 5000

# Fill your code: Simulate pinball
dt_pinball =0.001
coeff_rest =0.9

init_pos =[0.5, 1.0]
init_vel =[1.5, 0.5]

[p_hist_pinball, v_hist_pinball, t_hist_pinball] = simulate_pinball(coeff_rest, init_pos, init_vel, dt_pinball, walls, wall_norms, wall_tan, N_pinball)

# %%
# Visualize Pinball Matplotlib: No need to change
def plot_pinball(q, ts, walls, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  # m, c, l, g, mu, dt = params
  wall1, = ax.plot([walls[0][0][0], walls[0][1][0]], [walls[0][0][1], walls[0][1][1]], 'b', lw=1)     
  wall2, = ax.plot([walls[1][0][0], walls[1][1][0]], [walls[1][0][1], walls[1][1][1]], 'b', lw=1)     
  wall3, = ax.plot([walls[2][0][0], walls[2][1][0]], [walls[2][0][1], walls[2][1][1]], 'b', lw=1)     
  wall4, = ax.plot([walls[3][0][0], walls[3][1][0]], [walls[3][0][1], walls[3][1][1]], 'b', lw=1)     
  ball, = ax.plot([0], [0], 'ro', markersize=12)     
  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -1, 2))            
  ax.set_ylim((-0.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(q)//num_frames
  def drawFrame(k):
    k = interval*k
    q0 = q[k]
    ball.set_data([q0[0]], [q0[1]])
    txt_title.set_text('t = {:.2f} sec'.format(ts[k]))
    return ball,
  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
anim = plot_pinball(p_hist_pinball, t_hist_pinball, walls, num_frames= 100)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Q.2.(b) [5 pts] **What is the position and velocity of the ball after 1, 2, 3 sec ?**

# %%
# Fill your code: Print the position and velocity of the ball @ 1, 2, 3 sec
print(f"1 sec pos:{p_hist_pinball[1000]},vel:{v_hist_pinball[1000]}")
print(f"2 sec pos:{p_hist_pinball[2000]},vel:{v_hist_pinball[2000]}")
print(f"3 sec pos:{p_hist_pinball[3000]},vel:{v_hist_pinball[3000]}")
# Out:
# 1 sec pos:[0.09905 1.5    ],vel:[-1.35  0.5 ]
# 2 sec pos:[0.8844125 1.99905  ],vel:[-1.0935 -0.45  ]
# 3 sec pos:[0.1898213 1.54905  ],vel:[ 0.98415 -0.45   ]

# %% [markdown]
# ## Q.2.(c) [10 pts] **Plot the kinetic energy of the ball. Based on the plot explain how the ball loses its energy (Note: The pinball's mass is 1 kg)**

# %%
kin_energy = np.zeros(N_pinball)
m=1
# Fill your code: Compute kinetic energy of the ball and plot
for i in range(len(v_hist_pinball)):
   v_actual=np.power(v_hist_pinball[i,0],2)+np.power(v_hist_pinball[i,1],2)
   kin_energy[i]=1/2*v_actual*m
plt.plot(t_hist_pinball, kin_energy)
plt.show()

# %% [markdown]
# # Q.3 Swing Stick
# <img src="https://github.com/DARoSLab/CS403-Intro-Robotics/blob/main/hws/hw6/SwingArm.png?raw=true" width="500">

# %% [markdown]
# ## Q.3.(a) [20 pts] Implement a swing stick simulation.
# Use parameters, [$m, I, c, l, \mu, dt$] = [1, 0.05, 0.5, 1.0, 0, 0.001].
#
# Simulate the case when [$\theta_0, \dot{\theta}_0$] = [0, 0] and $F$ is applied at the tip of the arm during 0.05 sec to the vertical direction.

# %%
def sim_step(theta, theta_dot, F, tau , params=None):
  m, I, c, l, mu, dt = params
  print("in sim")
  # Fill your code: implement dynamics to compute the angular acceleration
  theta_ddot =(tau+l*np.cos(theta)*F-mu*theta_dot)/(I+np.power(c,2)*m)
  print(theta_ddot)
  # Fill your code: Semi-implciti Euler integration
  th_dot =theta_dot+dt*theta_ddot
  th =theta+dt*th_dot
  print([th,th_dot])
  return [th, th_dot]
  
def simulate_stick(theta=0, theta_dot=0, F=50, tau=0, F_duration=0.05, F_start_time=0.0, T=1.0, params=None):
  dt = params[-1]
  ts = np.linspace(0, T, int(T/dt))
  theta_hist = [theta]
  theta_dot_hist = [theta_dot]
 
  # Fill your code: Implement the case that the external force pushes the tip of the arm
  #tz=0
  for i, t in enumerate(ts):

    if t>=F_start_time and t<=F_start_time + F_duration:
      [theta, theta_dot] = sim_step(theta, theta_dot, F, tau, params=params)
    else:
      [theta, theta_dot] = sim_step(theta, theta_dot, 0, tau, params=params)
    theta_hist.append(theta)
    theta_dot_hist.append(theta_dot)

  ts = ts.tolist()
  ts.append(T)
  return [theta_hist, theta_dot_hist, ts]

# %%
# Visualization code: Do not need to change
def plot_stick(q, ts, params, num_frames= 100):
  fig= plt.figure(figsize=(10,10))
  ax = plt.subplot(1,1,1)   
  m, I, c, l, mu, dt = params
  link1, = ax.plot([], [], 'b', lw=10)     # ax.plot returns a list of 2D line objects  
  txt_title = ax.set_title('')
  
  ax.set_xlim(( -2.5, 2.5))    # Canvas size        
  ax.set_ylim((-2.5, 2.5))
  txt_title = ax.set_title('')
  interval = len(q)//num_frames

  def drawFrame(k):
    k = interval*k
    q0 = q[k]
    rA = [l*np.cos(q0), l*np.sin(q0)]
    x1 = 0
    x2 = rA[0]
    y1 = 0
    y2 = rA[1]
    link1.set_data([x1, x2], [y1, y2])
    txt_title.set_text('t = {:.2f} sec'.format(ts[k]))
    return link1,

  anim = animation.FuncAnimation(fig, drawFrame, frames=num_frames, interval=interval, blit=True)
  return anim

# %%
# Let's use param: [mass, Inertia, CoM, length, friction coefficient, delta_t]
# Fill your code: Run simulation
params=[1, 0.05, 0.5, 1.0, 0, 0.001]
[theta_hist, theta_dot_hist, ts] =simulate_stick(theta=0, theta_dot=0, F=50, tau=0, F_duration=0.05, F_start_time=0.0, T=1.0,params=params)
# Out:
# in sim
# 166.66666666666669
# [0.0001666666666666667, 0.16666666666666669]
# in sim
# 166.6666643518519
# [0.0004999999976851852, 0.3333333310185186]
# in sim
# 166.66664583333397
# [0.000999999974537038, 0.4999999768518526]
# in sim
# 166.6665833333445
# [0.001666666534722235, 0.6666665601851971]
# in sim
# 166.66643518527545
# [0.0024999995300927077, 0.8333329953704726]
# in sim
# 166.66614583380039
# [0.0034999986712969805, 0.9999991412042729]
# in sim
# 166.6656458351505
# [0.004666663458336404, 1.1666647870394233]
# in sim
# 166.66485185764077
# [0.005999993097233468, 1.3333296388970641]
# in sim
# 166.66366668256939
# [0.007499986402813102, 1.4999933055796335]
# in sim
# 166.6619792056356
# [0.00916664168759837, 1.6666552847852691]
# in sim
# 166.65966443904603
# [0.010999956636822685, 1.8333149492243153]
# in sim
# 166.65658351450392
# [0.012999928169561505, 1.9999715327388192]
# in sim
# 166.6525836873003
# [0.015166552285987624, 2.1666241164261195]
# in sim
# 166.64749834174899
# [0.017499823900755492, 2.3332716147678685]
# in sim
# 166.64114699823364
# [0.019999736662521594, 2.4999127617661023]
# in sim
# 166.63333532215694
# [0.022666282759609854, 2.666546097088259]
# in sim
# 166.62385513510793
# [0.02549945271183322, 2.833169952223367]
# in sim
# 166.6124844285859
# [0.028499235148485173, 2.999782436651953]
# in sim
# 166.59898738064445
# [0.03166561657251777, 3.1663814240325974]
# in sim
# 166.58311437584223
# [0.03499858111092621, 3.3329645384084396]
# in sim
# 166.56460202891026
# [0.03849811025136356, 3.49952914043735]
# in sim
# 166.5431732125701
# [0.042164182565013475, 3.66607231364992]
# in sim
# 166.51853708995884
# [0.04599677341575335, 3.8325908507398787]
# in sim
# 166.49038915214092
# [0.04999585465564537, 3.9990812398920195]
# in sim
# 166.4584112612087
# [0.0541613943067986, 4.165539651153228]
# in sim
# 166.42227169949552
# [0.05849335622965132, 4.331961922852724]
# in sim
# 166.38162522544764
# [0.06299169977772949, 4.4983435480781715]
# in sim
# 166.33611313672142
# [0.06765637943894438, 4.664679661214893]
# in sim
# 166.28536334109418
# [0.07248734446350037, 4.830965024555987]
# in sim
# 166.22899043579525
# [0.07748453847849215, 4.997194014991782]
# in sim
# 166.16659579588529
# [0.08264789908927982, 5.1633606107876675]
# in sim
# 166.09776767232847
# [0.08797735746773981, 5.329458378459996]
# in sim
# 166.02208130042095
# [0.09347283792750023, 5.495480459760417]
# in sim
# 165.93909901925534
# [0.09913425748627991, 5.661419558779673]
# in sim
# 165.8483704029163
# [0.1049615254154625, 5.827267929182589]
# in sim
# 165.74943240411721
# [0.1109545427770492, 5.9930173615867055]
# in sim
# 165.64180951100053
# [0.11711320194814691, 6.158659171097706]
# in sim
# 165.5250139178367
# [0.12343738613316245, 6.324184185015542]
# in sim
# 165.398545710366
# [0.12992696886388835, 6.489582730725909]
# in sim
# 165.26189306653717
# [0.1365818134876808, 6.654844623792446]
# in sim
# 165.1145324734026
# [0.14340177264394666, 6.819959156265848]
# in sim
# 164.95592896093495
# [0.15038668772917343, 6.984915085226783]
# in sim
# 164.7855363535335
# [0.15753638835075376, 7.149700621580316]
# in sim
# 164.6027975399881
# [0.16485069176987407, 7.3143034191203045]
# in sim
# 164.40714476266743
# [0.17232940233375704, 7.478710563882972]
# in sim
# 164.197999926694
# [0.1799723108975667, 7.642908563809666]
# in sim
# 163.97477492986138
# [0.18777919423630623, 7.806883338739527]
# in sim
# 163.736872014039
# [0.1957498144470598, 7.970620210753566]
# in sim
# 163.48368413879766
# [0.20388391834195216, 8.134103894892364]
# in sim
# 163.21459537797287
# [0.2121812368322225, 8.297318490270337]
# in sim
# 0.0
# [0.22047855532249286, 8.297318490270337]
# in sim
# 0.0
# [0.2287758738127632, 8.297318490270337]
# in sim
# 0.0
# [0.23707319230303356, 8.297318490270337]
# in sim
# 0.0
# [0.2453705107933039, 8.297318490270337]
# in sim
# 0.0
# [0.25366782928357423, 8.297318490270337]
# in sim
# 0.0
# [0.26196514777384455, 8.297318490270337]
# in sim
# 0.0
# [0.2702624662641149, 8.297318490270337]
# in sim
# 0.0
# [0.2785597847543852, 8.297318490270337]
# in sim
# 0.0
# [0.2868571032446555, 8.297318490270337]
# in sim
# 0.0
# [0.29515442173492584, 8.297318490270337]
# in sim
# 0.0
# [0.30345174022519616, 8.297318490270337]
# in sim
# 0.0
# [0.3117490587154665, 8.297318490270337]
# in sim
# 0.0
# [0.3200463772057368, 8.297318490270337]
# in sim
# 0.0
# [0.32834369569600713, 8.297318490270337]
# in sim
# 0.0
# [0.33664101418627745, 8.297318490270337]
# in sim
# 0.0
# [0.3449383326765478, 8.297318490270337]
# in sim
# 0.0
# [0.3532356511668181, 8.297318490270337]
# in sim
# 0.0
# [0.3615329696570884, 8.297318490270337]
# in sim
# 0.0
# [0.36983028814735874, 8.297318490270337]
# in sim
# 0.0
# [0.37812760663762907, 8.297318490270337]
# in sim
# 0.0
# [0.3864249251278994, 8.297318490270337]
# in sim
# 0.0
# [0.3947222436181697, 8.297318490270337]
# in sim
# 0.0
# [0.40301956210844003, 8.297318490270337]
# in sim
# 0.0
# [0.41131688059871035, 8.297318490270337]
# in sim
# 0.0
# [0.4196141990889807, 8.297318490270337]
# in sim
# 0.0
# [0.427911517579251, 8.297318490270337]
# in sim
# 0.0
# [0.4362088360695213, 8.297318490270337]
# in sim
# 0.0
# [0.44450615455979164, 8.297318490270337]
# in sim
# 0.0
# [0.45280347305006197, 8.297318490270337]
# in sim
# 0.0
# [0.4611007915403323, 8.297318490270337]
# in sim
# 0.0
# [0.4693981100306026, 8.297318490270337]
# in sim
# 0.0
# [0.47769542852087293, 8.297318490270337]
# in sim
# 0.0
# [0.48599274701114326, 8.297318490270337]
# in sim
# 0.0
# [0.4942900655014136, 8.297318490270337]
# in sim
# 0.0
# [0.5025873839916839, 8.297318490270337]
# in sim
# 0.0
# [0.5108847024819543, 8.297318490270337]
# in sim
# 0.0
# [0.5191820209722247, 8.297318490270337]
# in sim
# 0.0
# [0.527479339462495, 8.297318490270337]
# in sim
# 0.0
# [0.5357766579527654, 8.297318490270337]
# in sim
# 0.0
# [0.5440739764430358, 8.297318490270337]
# in sim
# 0.0
# [0.5523712949333062, 8.297318490270337]
# in sim
# 0.0
# [0.5606686134235765, 8.297318490270337]
# in sim
# 0.0
# [0.5689659319138469, 8.297318490270337]
# in sim
# 0.0
# [0.5772632504041173, 8.297318490270337]
# in sim
# 0.0
# [0.5855605688943877, 8.297318490270337]
# in sim
# 0.0
# [0.5938578873846581, 8.297318490270337]
# in sim
# 0.0
# [0.6021552058749284, 8.297318490270337]
# in sim
# 0.0
# [0.6104525243651988, 8.297318490270337]
# in sim
# 0.0
# [0.6187498428554692, 8.297318490270337]
# in sim
# 0.0
# [0.6270471613457396, 8.297318490270337]
# in sim
# 0.0
# [0.63534447983601, 8.297318490270337]
# in sim
# 0.0
# [0.6436417983262803, 8.297318490270337]
# in sim
# 0.0
# [0.6519391168165507, 8.297318490270337]
# in sim
# 0.0
# [0.6602364353068211, 8.297318490270337]
# in sim
# 0.0
# [0.6685337537970915, 8.297318490270337]
# in sim
# 0.0
# [0.6768310722873618, 8.297318490270337]
# in sim
# 0.0
# [0.6851283907776322, 8.297318490270337]
# in sim
# 0.0
# [0.6934257092679026, 8.297318490270337]
# in sim
# 0.0
# [0.701723027758173, 8.297318490270337]
# in sim
# 0.0
# [0.7100203462484433, 8.297318490270337]
# in sim
# 0.0
# [0.7183176647387137, 8.297318490270337]
# in sim
# 0.0
# [0.7266149832289841, 8.297318490270337]
# in sim
# 0.0
# [0.7349123017192545, 8.297318490270337]
# in sim
# 0.0
# [0.7432096202095249, 8.297318490270337]
# in sim
# 0.0
# [0.7515069386997952, 8.297318490270337]
# in sim
# 0.0
# [0.7598042571900656, 8.297318490270337]
# in sim
# 0.0
# [0.768101575680336, 8.297318490270337]
# in sim
# 0.0
# [0.7763988941706064, 8.297318490270337]
# in sim
# 0.0
# [0.7846962126608767, 8.297318490270337]
# in sim
# 0.0
# [0.7929935311511471, 8.297318490270337]
# in sim
# 0.0
# [0.8012908496414175, 8.297318490270337]
# in sim
# 0.0
# [0.8095881681316879, 8.297318490270337]
# in sim
# 0.0
# [0.8178854866219583, 8.297318490270337]
# in sim
# 0.0
# [0.8261828051122286, 8.297318490270337]
# in sim
# 0.0
# [0.834480123602499, 8.297318490270337]
# in sim
# 0.0
# [0.8427774420927694, 8.297318490270337]
# in sim
# 0.0
# [0.8510747605830398, 8.297318490270337]
# in sim
# 0.0
# [0.8593720790733101, 8.297318490270337]
# in sim
# 0.0
# [0.8676693975635805, 8.297318490270337]
# in sim
# 0.0
# [0.8759667160538509, 8.297318490270337]
# in sim
# 0.0
# [0.8842640345441213, 8.297318490270337]
# in sim
# 0.0
# [0.8925613530343917, 8.297318490270337]
# in sim
# 0.0
# [0.900858671524662, 8.297318490270337]
# in sim
# 0.0
# [0.9091559900149324, 8.297318490270337]
# in sim
# 0.0
# [0.9174533085052028, 8.297318490270337]
# in sim
# 0.0
# [0.9257506269954732, 8.297318490270337]
# in sim
# 0.0
# [0.9340479454857435, 8.297318490270337]
# in sim
# 0.0
# [0.9423452639760139, 8.297318490270337]
# in sim
# 0.0
# [0.9506425824662843, 8.297318490270337]
# in sim
# 0.0
# [0.9589399009565547, 8.297318490270337]
# in sim
# 0.0
# [0.9672372194468251, 8.297318490270337]
# in sim
# 0.0
# [0.9755345379370954, 8.297318490270337]
# in sim
# 0.0
# [0.9838318564273658, 8.297318490270337]
# in sim
# 0.0
# [0.9921291749176362, 8.297318490270337]
# in sim
# 0.0
# [1.0004264934079066, 8.297318490270337]
# in sim
# 0.0
# [1.008723811898177, 8.297318490270337]
# in sim
# 0.0
# [1.0170211303884473, 8.297318490270337]
# in sim
# 0.0
# [1.0253184488787177, 8.297318490270337]
# in sim
# 0.0
# [1.033615767368988, 8.297318490270337]
# in sim
# 0.0
# [1.0419130858592585, 8.297318490270337]
# in sim
# 0.0
# [1.0502104043495288, 8.297318490270337]
# in sim
# 0.0
# [1.0585077228397992, 8.297318490270337]
# in sim
# 0.0
# [1.0668050413300696, 8.297318490270337]
# in sim
# 0.0
# [1.07510235982034, 8.297318490270337]
# in sim
# 0.0
# [1.0833996783106103, 8.297318490270337]
# in sim
# 0.0
# [1.0916969968008807, 8.297318490270337]
# in sim
# 0.0
# [1.099994315291151, 8.297318490270337]
# in sim
# 0.0
# [1.1082916337814215, 8.297318490270337]
# in sim
# 0.0
# [1.1165889522716919, 8.297318490270337]
# in sim
# 0.0
# [1.1248862707619622, 8.297318490270337]
# in sim
# 0.0
# [1.1331835892522326, 8.297318490270337]
# in sim
# 0.0
# [1.141480907742503, 8.297318490270337]
# in sim
# 0.0
# [1.1497782262327734, 8.297318490270337]
# in sim
# 0.0
# [1.1580755447230437, 8.297318490270337]
# in sim
# 0.0
# [1.1663728632133141, 8.297318490270337]
# in sim
# 0.0
# [1.1746701817035845, 8.297318490270337]
# in sim
# 0.0
# [1.1829675001938549, 8.297318490270337]
# in sim
# 0.0
# [1.1912648186841253, 8.297318490270337]
# in sim
# 0.0
# [1.1995621371743956, 8.297318490270337]
# in sim
# 0.0
# [1.207859455664666, 8.297318490270337]
# in sim
# 0.0
# [1.2161567741549364, 8.297318490270337]
# in sim
# 0.0
# [1.2244540926452068, 8.297318490270337]
# in sim
# 0.0
# [1.2327514111354771, 8.297318490270337]
# in sim
# 0.0
# [1.2410487296257475, 8.297318490270337]
# in sim
# 0.0
# [1.249346048116018, 8.297318490270337]
# in sim
# 0.0
# [1.2576433666062883, 8.297318490270337]
# in sim
# 0.0
# [1.2659406850965587, 8.297318490270337]
# in sim
# 0.0
# [1.274238003586829, 8.297318490270337]
# in sim
# 0.0
# [1.2825353220770994, 8.297318490270337]
# in sim
# 0.0
# [1.2908326405673698, 8.297318490270337]
# in sim
# 0.0
# [1.2991299590576402, 8.297318490270337]
# in sim
# 0.0
# [1.3074272775479105, 8.297318490270337]
# in sim
# 0.0
# [1.315724596038181, 8.297318490270337]
# in sim
# 0.0
# [1.3240219145284513, 8.297318490270337]
# in sim
# 0.0
# [1.3323192330187217, 8.297318490270337]
# in sim
# 0.0
# [1.340616551508992, 8.297318490270337]
# in sim
# 0.0
# [1.3489138699992624, 8.297318490270337]
# in sim
# 0.0
# [1.3572111884895328, 8.297318490270337]
# in sim
# 0.0
# [1.3655085069798032, 8.297318490270337]
# in sim
# 0.0
# [1.3738058254700736, 8.297318490270337]
# in sim
# 0.0
# [1.382103143960344, 8.297318490270337]
# in sim
# 0.0
# [1.3904004624506143, 8.297318490270337]
# in sim
# 0.0
# [1.3986977809408847, 8.297318490270337]
# in sim
# 0.0
# [1.406995099431155, 8.297318490270337]
# in sim
# 0.0
# [1.4152924179214255, 8.297318490270337]
# in sim
# 0.0
# [1.4235897364116958, 8.297318490270337]
# in sim
# 0.0
# [1.4318870549019662, 8.297318490270337]
# in sim
# 0.0
# [1.4401843733922366, 8.297318490270337]
# in sim
# 0.0
# [1.448481691882507, 8.297318490270337]
# in sim
# 0.0
# [1.4567790103727773, 8.297318490270337]
# in sim
# 0.0
# [1.4650763288630477, 8.297318490270337]
# in sim
# 0.0
# [1.473373647353318, 8.297318490270337]
# in sim
# 0.0
# [1.4816709658435885, 8.297318490270337]
# in sim
# 0.0
# [1.4899682843338589, 8.297318490270337]
# in sim
# 0.0
# [1.4982656028241292, 8.297318490270337]
# in sim
# 0.0
# [1.5065629213143996, 8.297318490270337]
# in sim
# 0.0
# [1.51486023980467, 8.297318490270337]
# in sim
# 0.0
# [1.5231575582949404, 8.297318490270337]
# in sim
# 0.0
# [1.5314548767852108, 8.297318490270337]
# in sim
# 0.0
# [1.5397521952754811, 8.297318490270337]
# in sim
# 0.0
# [1.5480495137657515, 8.297318490270337]
# in sim
# 0.0
# [1.5563468322560219, 8.297318490270337]
# in sim
# 0.0
# [1.5646441507462923, 8.297318490270337]
# in sim
# 0.0
# [1.5729414692365626, 8.297318490270337]
# in sim
# 0.0
# [1.581238787726833, 8.297318490270337]
# in sim
# 0.0
# [1.5895361062171034, 8.297318490270337]
# in sim
# 0.0
# [1.5978334247073738, 8.297318490270337]
# in sim
# 0.0
# [1.6061307431976442, 8.297318490270337]
# in sim
# 0.0
# [1.6144280616879145, 8.297318490270337]
# in sim
# 0.0
# [1.622725380178185, 8.297318490270337]
# in sim
# 0.0
# [1.6310226986684553, 8.297318490270337]
# in sim
# 0.0
# [1.6393200171587257, 8.297318490270337]
# in sim
# 0.0
# [1.647617335648996, 8.297318490270337]
# in sim
# 0.0
# [1.6559146541392664, 8.297318490270337]
# in sim
# 0.0
# [1.6642119726295368, 8.297318490270337]
# in sim
# 0.0
# [1.6725092911198072, 8.297318490270337]
# in sim
# 0.0
# [1.6808066096100776, 8.297318490270337]
# in sim
# 0.0
# [1.689103928100348, 8.297318490270337]
# in sim
# 0.0
# [1.6974012465906183, 8.297318490270337]
# in sim
# 0.0
# [1.7056985650808887, 8.297318490270337]
# in sim
# 0.0
# [1.713995883571159, 8.297318490270337]
# in sim
# 0.0
# [1.7222932020614294, 8.297318490270337]
# in sim
# 0.0
# [1.7305905205516998, 8.297318490270337]
# in sim
# 0.0
# [1.7388878390419702, 8.297318490270337]
# in sim
# 0.0
# [1.7471851575322406, 8.297318490270337]
# in sim
# 0.0
# [1.755482476022511, 8.297318490270337]
# in sim
# 0.0
# [1.7637797945127813, 8.297318490270337]
# in sim
# 0.0
# [1.7720771130030517, 8.297318490270337]
# in sim
# 0.0
# [1.780374431493322, 8.297318490270337]
# in sim
# 0.0
# [1.7886717499835925, 8.297318490270337]
# in sim
# 0.0
# [1.7969690684738628, 8.297318490270337]
# in sim
# 0.0
# [1.8052663869641332, 8.297318490270337]
# in sim
# 0.0
# [1.8135637054544036, 8.297318490270337]
# in sim
# 0.0
# [1.821861023944674, 8.297318490270337]
# in sim
# 0.0
# [1.8301583424349444, 8.297318490270337]
# in sim
# 0.0
# [1.8384556609252147, 8.297318490270337]
# in sim
# 0.0
# [1.846752979415485, 8.297318490270337]
# in sim
# 0.0
# [1.8550502979057555, 8.297318490270337]
# in sim
# 0.0
# [1.8633476163960259, 8.297318490270337]
# in sim
# 0.0
# [1.8716449348862962, 8.297318490270337]
# in sim
# 0.0
# [1.8799422533765666, 8.297318490270337]
# in sim
# 0.0
# [1.888239571866837, 8.297318490270337]
# in sim
# 0.0
# [1.8965368903571074, 8.297318490270337]
# in sim
# 0.0
# [1.9048342088473778, 8.297318490270337]
# in sim
# 0.0
# [1.9131315273376481, 8.297318490270337]
# in sim
# 0.0
# [1.9214288458279185, 8.297318490270337]
# in sim
# 0.0
# [1.9297261643181889, 8.297318490270337]
# in sim
# 0.0
# [1.9380234828084593, 8.297318490270337]
# in sim
# 0.0
# [1.9463208012987296, 8.297318490270337]
# in sim
# 0.0
# [1.954618119789, 8.297318490270337]
# in sim
# 0.0
# [1.9629154382792704, 8.297318490270337]
# in sim
# 0.0
# [1.9712127567695408, 8.297318490270337]
# in sim
# 0.0
# [1.9795100752598112, 8.297318490270337]
# in sim
# 0.0
# [1.9878073937500815, 8.297318490270337]
# in sim
# 0.0
# [1.996104712240352, 8.297318490270337]
# in sim
# 0.0
# [2.0044020307306223, 8.297318490270337]
# in sim
# 0.0
# [2.0126993492208927, 8.297318490270337]
# in sim
# 0.0
# [2.020996667711163, 8.297318490270337]
# in sim
# 0.0
# [2.0292939862014334, 8.297318490270337]
# in sim
# 0.0
# [2.037591304691704, 8.297318490270337]
# in sim
# 0.0
# [2.045888623181974, 8.297318490270337]
# in sim
# 0.0
# [2.0541859416722446, 8.297318490270337]
# in sim
# 0.0
# [2.062483260162515, 8.297318490270337]
# in sim
# 0.0
# [2.0707805786527853, 8.297318490270337]
# in sim
# 0.0
# [2.0790778971430557, 8.297318490270337]
# in sim
# 0.0
# [2.087375215633326, 8.297318490270337]
# in sim
# 0.0
# [2.0956725341235964, 8.297318490270337]
# in sim
# 0.0
# [2.103969852613867, 8.297318490270337]
# in sim
# 0.0
# [2.112267171104137, 8.297318490270337]
# in sim
# 0.0
# [2.1205644895944076, 8.297318490270337]
# in sim
# 0.0
# [2.128861808084678, 8.297318490270337]
# in sim
# 0.0
# [2.1371591265749483, 8.297318490270337]
# in sim
# 0.0
# [2.1454564450652187, 8.297318490270337]
# in sim
# 0.0
# [2.153753763555489, 8.297318490270337]
# in sim
# 0.0
# [2.1620510820457595, 8.297318490270337]
# in sim
# 0.0
# [2.17034840053603, 8.297318490270337]
# in sim
# 0.0
# [2.1786457190263, 8.297318490270337]
# in sim
# 0.0
# [2.1869430375165706, 8.297318490270337]
# in sim
# 0.0
# [2.195240356006841, 8.297318490270337]
# in sim
# 0.0
# [2.2035376744971114, 8.297318490270337]
# in sim
# 0.0
# [2.2118349929873817, 8.297318490270337]
# in sim
# 0.0
# [2.220132311477652, 8.297318490270337]
# in sim
# 0.0
# [2.2284296299679225, 8.297318490270337]
# in sim
# 0.0
# [2.236726948458193, 8.297318490270337]
# in sim
# 0.0
# [2.2450242669484632, 8.297318490270337]
# in sim
# 0.0
# [2.2533215854387336, 8.297318490270337]
# in sim
# 0.0
# [2.261618903929004, 8.297318490270337]
# in sim
# 0.0
# [2.2699162224192744, 8.297318490270337]
# in sim
# 0.0
# [2.2782135409095448, 8.297318490270337]
# in sim
# 0.0
# [2.286510859399815, 8.297318490270337]
# in sim
# 0.0
# [2.2948081778900855, 8.297318490270337]
# in sim
# 0.0
# [2.303105496380356, 8.297318490270337]
# in sim
# 0.0
# [2.3114028148706263, 8.297318490270337]
# in sim
# 0.0
# [2.3197001333608966, 8.297318490270337]
# in sim
# 0.0
# [2.327997451851167, 8.297318490270337]
# in sim
# 0.0
# [2.3362947703414374, 8.297318490270337]
# in sim
# 0.0
# [2.3445920888317078, 8.297318490270337]
# in sim
# 0.0
# [2.352889407321978, 8.297318490270337]
# in sim
# 0.0
# [2.3611867258122485, 8.297318490270337]
# in sim
# 0.0
# [2.369484044302519, 8.297318490270337]
# in sim
# 0.0
# [2.3777813627927893, 8.297318490270337]
# in sim
# 0.0
# [2.3860786812830597, 8.297318490270337]
# in sim
# 0.0
# [2.39437599977333, 8.297318490270337]
# in sim
# 0.0
# [2.4026733182636004, 8.297318490270337]
# in sim
# 0.0
# [2.410970636753871, 8.297318490270337]
# in sim
# 0.0
# [2.419267955244141, 8.297318490270337]
# in sim
# 0.0
# [2.4275652737344116, 8.297318490270337]
# in sim
# 0.0
# [2.435862592224682, 8.297318490270337]
# in sim
# 0.0
# [2.4441599107149523, 8.297318490270337]
# in sim
# 0.0
# [2.4524572292052227, 8.297318490270337]
# in sim
# 0.0
# [2.460754547695493, 8.297318490270337]
# in sim
# 0.0
# [2.4690518661857634, 8.297318490270337]
# in sim
# 0.0
# [2.477349184676034, 8.297318490270337]
# in sim
# 0.0
# [2.485646503166304, 8.297318490270337]
# in sim
# 0.0
# [2.4939438216565746, 8.297318490270337]
# in sim
# 0.0
# [2.502241140146845, 8.297318490270337]
# in sim
# 0.0
# [2.5105384586371153, 8.297318490270337]
# in sim
# 0.0
# [2.5188357771273857, 8.297318490270337]
# in sim
# 0.0
# [2.527133095617656, 8.297318490270337]
# in sim
# 0.0
# [2.5354304141079265, 8.297318490270337]
# in sim
# 0.0
# [2.543727732598197, 8.297318490270337]
# in sim
# 0.0
# [2.5520250510884672, 8.297318490270337]
# in sim
# 0.0
# [2.5603223695787376, 8.297318490270337]
# in sim
# 0.0
# [2.568619688069008, 8.297318490270337]
# in sim
# 0.0
# [2.5769170065592784, 8.297318490270337]
# in sim
# 0.0
# [2.5852143250495487, 8.297318490270337]
# in sim
# 0.0
# [2.593511643539819, 8.297318490270337]
# in sim
# 0.0
# [2.6018089620300895, 8.297318490270337]
# in sim
# 0.0
# [2.61010628052036, 8.297318490270337]
# in sim
# 0.0
# [2.6184035990106302, 8.297318490270337]
# in sim
# 0.0
# [2.6267009175009006, 8.297318490270337]
# in sim
# 0.0
# [2.634998235991171, 8.297318490270337]
# in sim
# 0.0
# [2.6432955544814414, 8.297318490270337]
# in sim
# 0.0
# [2.6515928729717118, 8.297318490270337]
# in sim
# 0.0
# [2.659890191461982, 8.297318490270337]
# in sim
# 0.0
# [2.6681875099522525, 8.297318490270337]
# in sim
# 0.0
# [2.676484828442523, 8.297318490270337]
# in sim
# 0.0
# [2.6847821469327933, 8.297318490270337]
# in sim
# 0.0
# [2.6930794654230636, 8.297318490270337]
# in sim
# 0.0
# [2.701376783913334, 8.297318490270337]
# in sim
# 0.0
# [2.7096741024036044, 8.297318490270337]
# in sim
# 0.0
# [2.717971420893875, 8.297318490270337]
# in sim
# 0.0
# [2.726268739384145, 8.297318490270337]
# in sim
# 0.0
# [2.7345660578744155, 8.297318490270337]
# in sim
# 0.0
# [2.742863376364686, 8.297318490270337]
# in sim
# 0.0
# [2.7511606948549563, 8.297318490270337]
# in sim
# 0.0
# [2.7594580133452267, 8.297318490270337]
# in sim
# 0.0
# [2.767755331835497, 8.297318490270337]
# in sim
# 0.0
# [2.7760526503257674, 8.297318490270337]
# in sim
# 0.0
# [2.784349968816038, 8.297318490270337]
# in sim
# 0.0
# [2.792647287306308, 8.297318490270337]
# in sim
# 0.0
# [2.8009446057965786, 8.297318490270337]
# in sim
# 0.0
# [2.809241924286849, 8.297318490270337]
# in sim
# 0.0
# [2.8175392427771193, 8.297318490270337]
# in sim
# 0.0
# [2.8258365612673897, 8.297318490270337]
# in sim
# 0.0
# [2.83413387975766, 8.297318490270337]
# in sim
# 0.0
# [2.8424311982479304, 8.297318490270337]
# in sim
# 0.0
# [2.850728516738201, 8.297318490270337]
# in sim
# 0.0
# [2.859025835228471, 8.297318490270337]
# in sim
# 0.0
# [2.8673231537187416, 8.297318490270337]
# in sim
# 0.0
# [2.875620472209012, 8.297318490270337]
# in sim
# 0.0
# [2.8839177906992823, 8.297318490270337]
# in sim
# 0.0
# [2.8922151091895527, 8.297318490270337]
# in sim
# 0.0
# [2.900512427679823, 8.297318490270337]
# in sim
# 0.0
# [2.9088097461700935, 8.297318490270337]
# in sim
# 0.0
# [2.917107064660364, 8.297318490270337]
# in sim
# 0.0
# [2.9254043831506342, 8.297318490270337]
# in sim
# 0.0
# [2.9337017016409046, 8.297318490270337]
# in sim
# 0.0
# [2.941999020131175, 8.297318490270337]
# in sim
# 0.0
# [2.9502963386214454, 8.297318490270337]
# in sim
# 0.0
# [2.9585936571117157, 8.297318490270337]
# in sim
# 0.0
# [2.966890975601986, 8.297318490270337]
# in sim
# 0.0
# [2.9751882940922565, 8.297318490270337]
# in sim
# 0.0
# [2.983485612582527, 8.297318490270337]
# in sim
# 0.0
# [2.9917829310727972, 8.297318490270337]
# in sim
# 0.0
# [3.0000802495630676, 8.297318490270337]
# in sim
# 0.0
# [3.008377568053338, 8.297318490270337]
# in sim
# 0.0
# [3.0166748865436084, 8.297318490270337]
# in sim
# 0.0
# [3.0249722050338788, 8.297318490270337]
# in sim
# 0.0
# [3.033269523524149, 8.297318490270337]
# in sim
# 0.0
# [3.0415668420144195, 8.297318490270337]
# in sim
# 0.0
# [3.04986416050469, 8.297318490270337]
# in sim
# 0.0
# [3.0581614789949603, 8.297318490270337]
# in sim
# 0.0
# [3.0664587974852306, 8.297318490270337]
# in sim
# 0.0
# [3.074756115975501, 8.297318490270337]
# in sim
# 0.0
# [3.0830534344657714, 8.297318490270337]
# in sim
# 0.0
# [3.091350752956042, 8.297318490270337]
# in sim
# 0.0
# [3.099648071446312, 8.297318490270337]
# in sim
# 0.0
# [3.1079453899365825, 8.297318490270337]
# in sim
# 0.0
# [3.116242708426853, 8.297318490270337]
# in sim
# 0.0
# [3.1245400269171233, 8.297318490270337]
# in sim
# 0.0
# [3.1328373454073937, 8.297318490270337]
# in sim
# 0.0
# [3.141134663897664, 8.297318490270337]
# in sim
# 0.0
# [3.1494319823879344, 8.297318490270337]
# in sim
# 0.0
# [3.157729300878205, 8.297318490270337]
# in sim
# 0.0
# [3.166026619368475, 8.297318490270337]
# in sim
# 0.0
# [3.1743239378587456, 8.297318490270337]
# in sim
# 0.0
# [3.182621256349016, 8.297318490270337]
# in sim
# 0.0
# [3.1909185748392863, 8.297318490270337]
# in sim
# 0.0
# [3.1992158933295567, 8.297318490270337]
# in sim
# 0.0
# [3.207513211819827, 8.297318490270337]
# in sim
# 0.0
# [3.2158105303100974, 8.297318490270337]
# in sim
# 0.0
# [3.224107848800368, 8.297318490270337]
# in sim
# 0.0
# [3.232405167290638, 8.297318490270337]
# in sim
# 0.0
# [3.2407024857809086, 8.297318490270337]
# in sim
# 0.0
# [3.248999804271179, 8.297318490270337]
# in sim
# 0.0
# [3.2572971227614493, 8.297318490270337]
# in sim
# 0.0
# [3.2655944412517197, 8.297318490270337]
# in sim
# 0.0
# [3.27389175974199, 8.297318490270337]
# in sim
# 0.0
# [3.2821890782322605, 8.297318490270337]
# in sim
# 0.0
# [3.290486396722531, 8.297318490270337]
# in sim
# 0.0
# [3.2987837152128012, 8.297318490270337]
# in sim
# 0.0
# [3.3070810337030716, 8.297318490270337]
# in sim
# 0.0
# [3.315378352193342, 8.297318490270337]
# in sim
# 0.0
# [3.3236756706836124, 8.297318490270337]
# in sim
# 0.0
# [3.3319729891738827, 8.297318490270337]
# in sim
# 0.0
# [3.340270307664153, 8.297318490270337]
# in sim
# 0.0
# [3.3485676261544235, 8.297318490270337]
# in sim
# 0.0
# [3.356864944644694, 8.297318490270337]
# in sim
# 0.0
# [3.3651622631349642, 8.297318490270337]
# in sim
# 0.0
# [3.3734595816252346, 8.297318490270337]
# in sim
# 0.0
# [3.381756900115505, 8.297318490270337]
# in sim
# 0.0
# [3.3900542186057754, 8.297318490270337]
# in sim
# 0.0
# [3.3983515370960458, 8.297318490270337]
# in sim
# 0.0
# [3.406648855586316, 8.297318490270337]
# in sim
# 0.0
# [3.4149461740765865, 8.297318490270337]
# in sim
# 0.0
# [3.423243492566857, 8.297318490270337]
# in sim
# 0.0
# [3.4315408110571273, 8.297318490270337]
# in sim
# 0.0
# [3.4398381295473976, 8.297318490270337]
# in sim
# 0.0
# [3.448135448037668, 8.297318490270337]
# in sim
# 0.0
# [3.4564327665279384, 8.297318490270337]
# in sim
# 0.0
# [3.464730085018209, 8.297318490270337]
# in sim
# 0.0
# [3.473027403508479, 8.297318490270337]
# in sim
# 0.0
# [3.4813247219987495, 8.297318490270337]
# in sim
# 0.0
# [3.48962204048902, 8.297318490270337]
# in sim
# 0.0
# [3.4979193589792903, 8.297318490270337]
# in sim
# 0.0
# [3.5062166774695607, 8.297318490270337]
# in sim
# 0.0
# [3.514513995959831, 8.297318490270337]
# in sim
# 0.0
# [3.5228113144501014, 8.297318490270337]
# in sim
# 0.0
# [3.531108632940372, 8.297318490270337]
# in sim
# 0.0
# [3.539405951430642, 8.297318490270337]
# in sim
# 0.0
# [3.5477032699209126, 8.297318490270337]
# in sim
# 0.0
# [3.556000588411183, 8.297318490270337]
# in sim
# 0.0
# [3.5642979069014533, 8.297318490270337]
# in sim
# 0.0
# [3.5725952253917237, 8.297318490270337]
# in sim
# 0.0
# [3.580892543881994, 8.297318490270337]
# in sim
# 0.0
# [3.5891898623722645, 8.297318490270337]
# in sim
# 0.0
# [3.597487180862535, 8.297318490270337]
# in sim
# 0.0
# [3.605784499352805, 8.297318490270337]
# in sim
# 0.0
# [3.6140818178430756, 8.297318490270337]
# in sim
# 0.0
# [3.622379136333346, 8.297318490270337]
# in sim
# 0.0
# [3.6306764548236163, 8.297318490270337]
# in sim
# 0.0
# [3.6389737733138867, 8.297318490270337]
# in sim
# 0.0
# [3.647271091804157, 8.297318490270337]
# in sim
# 0.0
# [3.6555684102944275, 8.297318490270337]
# in sim
# 0.0
# [3.663865728784698, 8.297318490270337]
# in sim
# 0.0
# [3.6721630472749682, 8.297318490270337]
# in sim
# 0.0
# [3.6804603657652386, 8.297318490270337]
# in sim
# 0.0
# [3.688757684255509, 8.297318490270337]
# in sim
# 0.0
# [3.6970550027457794, 8.297318490270337]
# in sim
# 0.0
# [3.7053523212360497, 8.297318490270337]
# in sim
# 0.0
# [3.71364963972632, 8.297318490270337]
# in sim
# 0.0
# [3.7219469582165905, 8.297318490270337]
# in sim
# 0.0
# [3.730244276706861, 8.297318490270337]
# in sim
# 0.0
# [3.7385415951971313, 8.297318490270337]
# in sim
# 0.0
# [3.7468389136874016, 8.297318490270337]
# in sim
# 0.0
# [3.755136232177672, 8.297318490270337]
# in sim
# 0.0
# [3.7634335506679424, 8.297318490270337]
# in sim
# 0.0
# [3.7717308691582128, 8.297318490270337]
# in sim
# 0.0
# [3.780028187648483, 8.297318490270337]
# in sim
# 0.0
# [3.7883255061387535, 8.297318490270337]
# in sim
# 0.0
# [3.796622824629024, 8.297318490270337]
# in sim
# 0.0
# [3.8049201431192943, 8.297318490270337]
# in sim
# 0.0
# [3.8132174616095647, 8.297318490270337]
# in sim
# 0.0
# [3.821514780099835, 8.297318490270337]
# in sim
# 0.0
# [3.8298120985901054, 8.297318490270337]
# in sim
# 0.0
# [3.838109417080376, 8.297318490270337]
# in sim
# 0.0
# [3.846406735570646, 8.297318490270337]
# in sim
# 0.0
# [3.8547040540609165, 8.297318490270337]
# in sim
# 0.0
# [3.863001372551187, 8.297318490270337]
# in sim
# 0.0
# [3.8712986910414573, 8.297318490270337]
# in sim
# 0.0
# [3.8795960095317277, 8.297318490270337]
# in sim
# 0.0
# [3.887893328021998, 8.297318490270337]
# in sim
# 0.0
# [3.8961906465122684, 8.297318490270337]
# in sim
# 0.0
# [3.904487965002539, 8.297318490270337]
# in sim
# 0.0
# [3.912785283492809, 8.297318490270337]
# in sim
# 0.0
# [3.9210826019830796, 8.297318490270337]
# in sim
# 0.0
# [3.92937992047335, 8.297318490270337]
# in sim
# 0.0
# [3.9376772389636203, 8.297318490270337]
# in sim
# 0.0
# [3.9459745574538907, 8.297318490270337]
# in sim
# 0.0
# [3.954271875944161, 8.297318490270337]
# in sim
# 0.0
# [3.9625691944344315, 8.297318490270337]
# in sim
# 0.0
# [3.970866512924702, 8.297318490270337]
# in sim
# 0.0
# [3.979163831414972, 8.297318490270337]
# in sim
# 0.0
# [3.9874611499052426, 8.297318490270337]
# in sim
# 0.0
# [3.995758468395513, 8.297318490270337]
# in sim
# 0.0
# [4.004055786885783, 8.297318490270337]
# in sim
# 0.0
# [4.012353105376054, 8.297318490270337]
# in sim
# 0.0
# [4.020650423866324, 8.297318490270337]
# in sim
# 0.0
# [4.0289477423565945, 8.297318490270337]
# in sim
# 0.0
# [4.037245060846865, 8.297318490270337]
# in sim
# 0.0
# [4.045542379337135, 8.297318490270337]
# in sim
# 0.0
# [4.053839697827406, 8.297318490270337]
# in sim
# 0.0
# [4.062137016317676, 8.297318490270337]
# in sim
# 0.0
# [4.070434334807946, 8.297318490270337]
# in sim
# 0.0
# [4.078731653298217, 8.297318490270337]
# in sim
# 0.0
# [4.087028971788487, 8.297318490270337]
# in sim
# 0.0
# [4.0953262902787575, 8.297318490270337]
# in sim
# 0.0
# [4.103623608769028, 8.297318490270337]
# in sim
# 0.0
# [4.111920927259298, 8.297318490270337]
# in sim
# 0.0
# [4.120218245749569, 8.297318490270337]
# in sim
# 0.0
# [4.128515564239839, 8.297318490270337]
# in sim
# 0.0
# [4.136812882730109, 8.297318490270337]
# in sim
# 0.0
# [4.14511020122038, 8.297318490270337]
# in sim
# 0.0
# [4.15340751971065, 8.297318490270337]
# in sim
# 0.0
# [4.1617048382009205, 8.297318490270337]
# in sim
# 0.0
# [4.170002156691191, 8.297318490270337]
# in sim
# 0.0
# [4.178299475181461, 8.297318490270337]
# in sim
# 0.0
# [4.186596793671732, 8.297318490270337]
# in sim
# 0.0
# [4.194894112162002, 8.297318490270337]
# in sim
# 0.0
# [4.203191430652272, 8.297318490270337]
# in sim
# 0.0
# [4.211488749142543, 8.297318490270337]
# in sim
# 0.0
# [4.219786067632813, 8.297318490270337]
# in sim
# 0.0
# [4.2280833861230835, 8.297318490270337]
# in sim
# 0.0
# [4.236380704613354, 8.297318490270337]
# in sim
# 0.0
# [4.244678023103624, 8.297318490270337]
# in sim
# 0.0
# [4.252975341593895, 8.297318490270337]
# in sim
# 0.0
# [4.261272660084165, 8.297318490270337]
# in sim
# 0.0
# [4.269569978574435, 8.297318490270337]
# in sim
# 0.0
# [4.277867297064706, 8.297318490270337]
# in sim
# 0.0
# [4.286164615554976, 8.297318490270337]
# in sim
# 0.0
# [4.294461934045247, 8.297318490270337]
# in sim
# 0.0
# [4.302759252535517, 8.297318490270337]
# in sim
# 0.0
# [4.311056571025787, 8.297318490270337]
# in sim
# 0.0
# [4.319353889516058, 8.297318490270337]
# in sim
# 0.0
# [4.327651208006328, 8.297318490270337]
# in sim
# 0.0
# [4.3359485264965985, 8.297318490270337]
# in sim
# 0.0
# [4.344245844986869, 8.297318490270337]
# in sim
# 0.0
# [4.352543163477139, 8.297318490270337]
# in sim
# 0.0
# [4.36084048196741, 8.297318490270337]
# in sim
# 0.0
# [4.36913780045768, 8.297318490270337]
# in sim
# 0.0
# [4.37743511894795, 8.297318490270337]
# in sim
# 0.0
# [4.385732437438221, 8.297318490270337]
# in sim
# 0.0
# [4.394029755928491, 8.297318490270337]
# in sim
# 0.0
# [4.4023270744187615, 8.297318490270337]
# in sim
# 0.0
# [4.410624392909032, 8.297318490270337]
# in sim
# 0.0
# [4.418921711399302, 8.297318490270337]
# in sim
# 0.0
# [4.427219029889573, 8.297318490270337]
# in sim
# 0.0
# [4.435516348379843, 8.297318490270337]
# in sim
# 0.0
# [4.443813666870113, 8.297318490270337]
# in sim
# 0.0
# [4.452110985360384, 8.297318490270337]
# in sim
# 0.0
# [4.460408303850654, 8.297318490270337]
# in sim
# 0.0
# [4.4687056223409245, 8.297318490270337]
# in sim
# 0.0
# [4.477002940831195, 8.297318490270337]
# in sim
# 0.0
# [4.485300259321465, 8.297318490270337]
# in sim
# 0.0
# [4.493597577811736, 8.297318490270337]
# in sim
# 0.0
# [4.501894896302006, 8.297318490270337]
# in sim
# 0.0
# [4.510192214792276, 8.297318490270337]
# in sim
# 0.0
# [4.518489533282547, 8.297318490270337]
# in sim
# 0.0
# [4.526786851772817, 8.297318490270337]
# in sim
# 0.0
# [4.5350841702630875, 8.297318490270337]
# in sim
# 0.0
# [4.543381488753358, 8.297318490270337]
# in sim
# 0.0
# [4.551678807243628, 8.297318490270337]
# in sim
# 0.0
# [4.559976125733899, 8.297318490270337]
# in sim
# 0.0
# [4.568273444224169, 8.297318490270337]
# in sim
# 0.0
# [4.576570762714439, 8.297318490270337]
# in sim
# 0.0
# [4.58486808120471, 8.297318490270337]
# in sim
# 0.0
# [4.59316539969498, 8.297318490270337]
# in sim
# 0.0
# [4.6014627181852505, 8.297318490270337]
# in sim
# 0.0
# [4.609760036675521, 8.297318490270337]
# in sim
# 0.0
# [4.618057355165791, 8.297318490270337]
# in sim
# 0.0
# [4.626354673656062, 8.297318490270337]
# in sim
# 0.0
# [4.634651992146332, 8.297318490270337]
# in sim
# 0.0
# [4.642949310636602, 8.297318490270337]
# in sim
# 0.0
# [4.651246629126873, 8.297318490270337]
# in sim
# 0.0
# [4.659543947617143, 8.297318490270337]
# in sim
# 0.0
# [4.667841266107414, 8.297318490270337]
# in sim
# 0.0
# [4.676138584597684, 8.297318490270337]
# in sim
# 0.0
# [4.684435903087954, 8.297318490270337]
# in sim
# 0.0
# [4.692733221578225, 8.297318490270337]
# in sim
# 0.0
# [4.701030540068495, 8.297318490270337]
# in sim
# 0.0
# [4.7093278585587655, 8.297318490270337]
# in sim
# 0.0
# [4.717625177049036, 8.297318490270337]
# in sim
# 0.0
# [4.725922495539306, 8.297318490270337]
# in sim
# 0.0
# [4.734219814029577, 8.297318490270337]
# in sim
# 0.0
# [4.742517132519847, 8.297318490270337]
# in sim
# 0.0
# [4.750814451010117, 8.297318490270337]
# in sim
# 0.0
# [4.759111769500388, 8.297318490270337]
# in sim
# 0.0
# [4.767409087990658, 8.297318490270337]
# in sim
# 0.0
# [4.7757064064809285, 8.297318490270337]
# in sim
# 0.0
# [4.784003724971199, 8.297318490270337]
# in sim
# 0.0
# [4.792301043461469, 8.297318490270337]
# in sim
# 0.0
# [4.80059836195174, 8.297318490270337]
# in sim
# 0.0
# [4.80889568044201, 8.297318490270337]
# in sim
# 0.0
# [4.81719299893228, 8.297318490270337]
# in sim
# 0.0
# [4.825490317422551, 8.297318490270337]
# in sim
# 0.0
# [4.833787635912821, 8.297318490270337]
# in sim
# 0.0
# [4.8420849544030915, 8.297318490270337]
# in sim
# 0.0
# [4.850382272893362, 8.297318490270337]
# in sim
# 0.0
# [4.858679591383632, 8.297318490270337]
# in sim
# 0.0
# [4.866976909873903, 8.297318490270337]
# in sim
# 0.0
# [4.875274228364173, 8.297318490270337]
# in sim
# 0.0
# [4.883571546854443, 8.297318490270337]
# in sim
# 0.0
# [4.891868865344714, 8.297318490270337]
# in sim
# 0.0
# [4.900166183834984, 8.297318490270337]
# in sim
# 0.0
# [4.9084635023252545, 8.297318490270337]
# in sim
# 0.0
# [4.916760820815525, 8.297318490270337]
# in sim
# 0.0
# [4.925058139305795, 8.297318490270337]
# in sim
# 0.0
# [4.933355457796066, 8.297318490270337]
# in sim
# 0.0
# [4.941652776286336, 8.297318490270337]
# in sim
# 0.0
# [4.949950094776606, 8.297318490270337]
# in sim
# 0.0
# [4.958247413266877, 8.297318490270337]
# in sim
# 0.0
# [4.966544731757147, 8.297318490270337]
# in sim
# 0.0
# [4.9748420502474175, 8.297318490270337]
# in sim
# 0.0
# [4.983139368737688, 8.297318490270337]
# in sim
# 0.0
# [4.991436687227958, 8.297318490270337]
# in sim
# 0.0
# [4.999734005718229, 8.297318490270337]
# in sim
# 0.0
# [5.008031324208499, 8.297318490270337]
# in sim
# 0.0
# [5.016328642698769, 8.297318490270337]
# in sim
# 0.0
# [5.02462596118904, 8.297318490270337]
# in sim
# 0.0
# [5.03292327967931, 8.297318490270337]
# in sim
# 0.0
# [5.041220598169581, 8.297318490270337]
# in sim
# 0.0
# [5.049517916659851, 8.297318490270337]
# in sim
# 0.0
# [5.057815235150121, 8.297318490270337]
# in sim
# 0.0
# [5.066112553640392, 8.297318490270337]
# in sim
# 0.0
# [5.074409872130662, 8.297318490270337]
# in sim
# 0.0
# [5.0827071906209325, 8.297318490270337]
# in sim
# 0.0
# [5.091004509111203, 8.297318490270337]
# in sim
# 0.0
# [5.099301827601473, 8.297318490270337]
# in sim
# 0.0
# [5.107599146091744, 8.297318490270337]
# in sim
# 0.0
# [5.115896464582014, 8.297318490270337]
# in sim
# 0.0
# [5.124193783072284, 8.297318490270337]
# in sim
# 0.0
# [5.132491101562555, 8.297318490270337]
# in sim
# 0.0
# [5.140788420052825, 8.297318490270337]
# in sim
# 0.0
# [5.1490857385430955, 8.297318490270337]
# in sim
# 0.0
# [5.157383057033366, 8.297318490270337]
# in sim
# 0.0
# [5.165680375523636, 8.297318490270337]
# in sim
# 0.0
# [5.173977694013907, 8.297318490270337]
# in sim
# 0.0
# [5.182275012504177, 8.297318490270337]
# in sim
# 0.0
# [5.190572330994447, 8.297318490270337]
# in sim
# 0.0
# [5.198869649484718, 8.297318490270337]
# in sim
# 0.0
# [5.207166967974988, 8.297318490270337]
# in sim
# 0.0
# [5.2154642864652585, 8.297318490270337]
# in sim
# 0.0
# [5.223761604955529, 8.297318490270337]
# in sim
# 0.0
# [5.232058923445799, 8.297318490270337]
# in sim
# 0.0
# [5.24035624193607, 8.297318490270337]
# in sim
# 0.0
# [5.24865356042634, 8.297318490270337]
# in sim
# 0.0
# [5.25695087891661, 8.297318490270337]
# in sim
# 0.0
# [5.265248197406881, 8.297318490270337]
# in sim
# 0.0
# [5.273545515897151, 8.297318490270337]
# in sim
# 0.0
# [5.2818428343874215, 8.297318490270337]
# in sim
# 0.0
# [5.290140152877692, 8.297318490270337]
# in sim
# 0.0
# [5.298437471367962, 8.297318490270337]
# in sim
# 0.0
# [5.306734789858233, 8.297318490270337]
# in sim
# 0.0
# [5.315032108348503, 8.297318490270337]
# in sim
# 0.0
# [5.323329426838773, 8.297318490270337]
# in sim
# 0.0
# [5.331626745329044, 8.297318490270337]
# in sim
# 0.0
# [5.339924063819314, 8.297318490270337]
# in sim
# 0.0
# [5.3482213823095845, 8.297318490270337]
# in sim
# 0.0
# [5.356518700799855, 8.297318490270337]
# in sim
# 0.0
# [5.364816019290125, 8.297318490270337]
# in sim
# 0.0
# [5.373113337780396, 8.297318490270337]
# in sim
# 0.0
# [5.381410656270666, 8.297318490270337]
# in sim
# 0.0
# [5.389707974760936, 8.297318490270337]
# in sim
# 0.0
# [5.398005293251207, 8.297318490270337]
# in sim
# 0.0
# [5.406302611741477, 8.297318490270337]
# in sim
# 0.0
# [5.414599930231748, 8.297318490270337]
# in sim
# 0.0
# [5.422897248722018, 8.297318490270337]
# in sim
# 0.0
# [5.431194567212288, 8.297318490270337]
# in sim
# 0.0
# [5.439491885702559, 8.297318490270337]
# in sim
# 0.0
# [5.447789204192829, 8.297318490270337]
# in sim
# 0.0
# [5.4560865226830995, 8.297318490270337]
# in sim
# 0.0
# [5.46438384117337, 8.297318490270337]
# in sim
# 0.0
# [5.47268115966364, 8.297318490270337]
# in sim
# 0.0
# [5.480978478153911, 8.297318490270337]
# in sim
# 0.0
# [5.489275796644181, 8.297318490270337]
# in sim
# 0.0
# [5.497573115134451, 8.297318490270337]
# in sim
# 0.0
# [5.505870433624722, 8.297318490270337]
# in sim
# 0.0
# [5.514167752114992, 8.297318490270337]
# in sim
# 0.0
# [5.5224650706052625, 8.297318490270337]
# in sim
# 0.0
# [5.530762389095533, 8.297318490270337]
# in sim
# 0.0
# [5.539059707585803, 8.297318490270337]
# in sim
# 0.0
# [5.547357026076074, 8.297318490270337]
# in sim
# 0.0
# [5.555654344566344, 8.297318490270337]
# in sim
# 0.0
# [5.563951663056614, 8.297318490270337]
# in sim
# 0.0
# [5.572248981546885, 8.297318490270337]
# in sim
# 0.0
# [5.580546300037155, 8.297318490270337]
# in sim
# 0.0
# [5.5888436185274255, 8.297318490270337]
# in sim
# 0.0
# [5.597140937017696, 8.297318490270337]
# in sim
# 0.0
# [5.605438255507966, 8.297318490270337]
# in sim
# 0.0
# [5.613735573998237, 8.297318490270337]
# in sim
# 0.0
# [5.622032892488507, 8.297318490270337]
# in sim
# 0.0
# [5.630330210978777, 8.297318490270337]
# in sim
# 0.0
# [5.638627529469048, 8.297318490270337]
# in sim
# 0.0
# [5.646924847959318, 8.297318490270337]
# in sim
# 0.0
# [5.6552221664495885, 8.297318490270337]
# in sim
# 0.0
# [5.663519484939859, 8.297318490270337]
# in sim
# 0.0
# [5.671816803430129, 8.297318490270337]
# in sim
# 0.0
# [5.6801141219204, 8.297318490270337]
# in sim
# 0.0
# [5.68841144041067, 8.297318490270337]
# in sim
# 0.0
# [5.69670875890094, 8.297318490270337]
# in sim
# 0.0
# [5.705006077391211, 8.297318490270337]
# in sim
# 0.0
# [5.713303395881481, 8.297318490270337]
# in sim
# 0.0
# [5.7216007143717516, 8.297318490270337]
# in sim
# 0.0
# [5.729898032862022, 8.297318490270337]
# in sim
# 0.0
# [5.738195351352292, 8.297318490270337]
# in sim
# 0.0
# [5.746492669842563, 8.297318490270337]
# in sim
# 0.0
# [5.754789988332833, 8.297318490270337]
# in sim
# 0.0
# [5.763087306823103, 8.297318490270337]
# in sim
# 0.0
# [5.771384625313374, 8.297318490270337]
# in sim
# 0.0
# [5.779681943803644, 8.297318490270337]
# in sim
# 0.0
# [5.787979262293915, 8.297318490270337]
# in sim
# 0.0
# [5.796276580784185, 8.297318490270337]
# in sim
# 0.0
# [5.804573899274455, 8.297318490270337]
# in sim
# 0.0
# [5.812871217764726, 8.297318490270337]
# in sim
# 0.0
# [5.821168536254996, 8.297318490270337]
# in sim
# 0.0
# [5.8294658547452665, 8.297318490270337]
# in sim
# 0.0
# [5.837763173235537, 8.297318490270337]
# in sim
# 0.0
# [5.846060491725807, 8.297318490270337]
# in sim
# 0.0
# [5.854357810216078, 8.297318490270337]
# in sim
# 0.0
# [5.862655128706348, 8.297318490270337]
# in sim
# 0.0
# [5.870952447196618, 8.297318490270337]
# in sim
# 0.0
# [5.879249765686889, 8.297318490270337]
# in sim
# 0.0
# [5.887547084177159, 8.297318490270337]
# in sim
# 0.0
# [5.8958444026674295, 8.297318490270337]
# in sim
# 0.0
# [5.9041417211577, 8.297318490270337]
# in sim
# 0.0
# [5.91243903964797, 8.297318490270337]
# in sim
# 0.0
# [5.920736358138241, 8.297318490270337]
# in sim
# 0.0
# [5.929033676628511, 8.297318490270337]
# in sim
# 0.0
# [5.937330995118781, 8.297318490270337]
# in sim
# 0.0
# [5.945628313609052, 8.297318490270337]
# in sim
# 0.0
# [5.953925632099322, 8.297318490270337]
# in sim
# 0.0
# [5.9622229505895925, 8.297318490270337]
# in sim
# 0.0
# [5.970520269079863, 8.297318490270337]
# in sim
# 0.0
# [5.978817587570133, 8.297318490270337]
# in sim
# 0.0
# [5.987114906060404, 8.297318490270337]
# in sim
# 0.0
# [5.995412224550674, 8.297318490270337]
# in sim
# 0.0
# [6.003709543040944, 8.297318490270337]
# in sim
# 0.0
# [6.012006861531215, 8.297318490270337]
# in sim
# 0.0
# [6.020304180021485, 8.297318490270337]
# in sim
# 0.0
# [6.0286014985117555, 8.297318490270337]
# in sim
# 0.0
# [6.036898817002026, 8.297318490270337]
# in sim
# 0.0
# [6.045196135492296, 8.297318490270337]
# in sim
# 0.0
# [6.053493453982567, 8.297318490270337]
# in sim
# 0.0
# [6.061790772472837, 8.297318490270337]
# in sim
# 0.0
# [6.070088090963107, 8.297318490270337]
# in sim
# 0.0
# [6.078385409453378, 8.297318490270337]
# in sim
# 0.0
# [6.086682727943648, 8.297318490270337]
# in sim
# 0.0
# [6.0949800464339186, 8.297318490270337]
# in sim
# 0.0
# [6.103277364924189, 8.297318490270337]
# in sim
# 0.0
# [6.111574683414459, 8.297318490270337]
# in sim
# 0.0
# [6.11987200190473, 8.297318490270337]
# in sim
# 0.0
# [6.128169320395, 8.297318490270337]
# in sim
# 0.0
# [6.13646663888527, 8.297318490270337]
# in sim
# 0.0
# [6.144763957375541, 8.297318490270337]
# in sim
# 0.0
# [6.153061275865811, 8.297318490270337]
# in sim
# 0.0
# [6.161358594356082, 8.297318490270337]
# in sim
# 0.0
# [6.169655912846352, 8.297318490270337]
# in sim
# 0.0
# [6.177953231336622, 8.297318490270337]
# in sim
# 0.0
# [6.186250549826893, 8.297318490270337]
# in sim
# 0.0
# [6.194547868317163, 8.297318490270337]
# in sim
# 0.0
# [6.2028451868074335, 8.297318490270337]
# in sim
# 0.0
# [6.211142505297704, 8.297318490270337]
# in sim
# 0.0
# [6.219439823787974, 8.297318490270337]
# in sim
# 0.0
# [6.227737142278245, 8.297318490270337]
# in sim
# 0.0
# [6.236034460768515, 8.297318490270337]
# in sim
# 0.0
# [6.244331779258785, 8.297318490270337]
# in sim
# 0.0
# [6.252629097749056, 8.297318490270337]
# in sim
# 0.0
# [6.260926416239326, 8.297318490270337]
# in sim
# 0.0
# [6.2692237347295965, 8.297318490270337]
# in sim
# 0.0
# [6.277521053219867, 8.297318490270337]
# in sim
# 0.0
# [6.285818371710137, 8.297318490270337]
# in sim
# 0.0
# [6.294115690200408, 8.297318490270337]
# in sim
# 0.0
# [6.302413008690678, 8.297318490270337]
# in sim
# 0.0
# [6.310710327180948, 8.297318490270337]
# in sim
# 0.0
# [6.319007645671219, 8.297318490270337]
# in sim
# 0.0
# [6.327304964161489, 8.297318490270337]
# in sim
# 0.0
# [6.3356022826517595, 8.297318490270337]
# in sim
# 0.0
# [6.34389960114203, 8.297318490270337]
# in sim
# 0.0
# [6.3521969196323, 8.297318490270337]
# in sim
# 0.0
# [6.360494238122571, 8.297318490270337]
# in sim
# 0.0
# [6.368791556612841, 8.297318490270337]
# in sim
# 0.0
# [6.377088875103111, 8.297318490270337]
# in sim
# 0.0
# [6.385386193593382, 8.297318490270337]
# in sim
# 0.0
# [6.393683512083652, 8.297318490270337]
# in sim
# 0.0
# [6.4019808305739225, 8.297318490270337]
# in sim
# 0.0
# [6.410278149064193, 8.297318490270337]
# in sim
# 0.0
# [6.418575467554463, 8.297318490270337]
# in sim
# 0.0
# [6.426872786044734, 8.297318490270337]
# in sim
# 0.0
# [6.435170104535004, 8.297318490270337]
# in sim
# 0.0
# [6.443467423025274, 8.297318490270337]
# in sim
# 0.0
# [6.451764741515545, 8.297318490270337]
# in sim
# 0.0
# [6.460062060005815, 8.297318490270337]
# in sim
# 0.0
# [6.4683593784960856, 8.297318490270337]
# in sim
# 0.0
# [6.476656696986356, 8.297318490270337]
# in sim
# 0.0
# [6.484954015476626, 8.297318490270337]
# in sim
# 0.0
# [6.493251333966897, 8.297318490270337]
# in sim
# 0.0
# [6.501548652457167, 8.297318490270337]
# in sim
# 0.0
# [6.509845970947437, 8.297318490270337]
# in sim
# 0.0
# [6.518143289437708, 8.297318490270337]
# in sim
# 0.0
# [6.526440607927978, 8.297318490270337]
# in sim
# 0.0
# [6.534737926418249, 8.297318490270337]
# in sim
# 0.0
# [6.543035244908519, 8.297318490270337]
# in sim
# 0.0
# [6.551332563398789, 8.297318490270337]
# in sim
# 0.0
# [6.55962988188906, 8.297318490270337]
# in sim
# 0.0
# [6.56792720037933, 8.297318490270337]
# in sim
# 0.0
# [6.5762245188696005, 8.297318490270337]
# in sim
# 0.0
# [6.584521837359871, 8.297318490270337]
# in sim
# 0.0
# [6.592819155850141, 8.297318490270337]
# in sim
# 0.0
# [6.601116474340412, 8.297318490270337]
# in sim
# 0.0
# [6.609413792830682, 8.297318490270337]
# in sim
# 0.0
# [6.617711111320952, 8.297318490270337]
# in sim
# 0.0
# [6.626008429811223, 8.297318490270337]
# in sim
# 0.0
# [6.634305748301493, 8.297318490270337]
# in sim
# 0.0
# [6.6426030667917635, 8.297318490270337]
# in sim
# 0.0
# [6.650900385282034, 8.297318490270337]
# in sim
# 0.0
# [6.659197703772304, 8.297318490270337]
# in sim
# 0.0
# [6.667495022262575, 8.297318490270337]
# in sim
# 0.0
# [6.675792340752845, 8.297318490270337]
# in sim
# 0.0
# [6.684089659243115, 8.297318490270337]
# in sim
# 0.0
# [6.692386977733386, 8.297318490270337]
# in sim
# 0.0
# [6.700684296223656, 8.297318490270337]
# in sim
# 0.0
# [6.7089816147139265, 8.297318490270337]
# in sim
# 0.0
# [6.717278933204197, 8.297318490270337]
# in sim
# 0.0
# [6.725576251694467, 8.297318490270337]
# in sim
# 0.0
# [6.733873570184738, 8.297318490270337]
# in sim
# 0.0
# [6.742170888675008, 8.297318490270337]
# in sim
# 0.0
# [6.750468207165278, 8.297318490270337]
# in sim
# 0.0
# [6.758765525655549, 8.297318490270337]
# in sim
# 0.0
# [6.767062844145819, 8.297318490270337]
# in sim
# 0.0
# [6.7753601626360895, 8.297318490270337]
# in sim
# 0.0
# [6.78365748112636, 8.297318490270337]
# in sim
# 0.0
# [6.79195479961663, 8.297318490270337]
# in sim
# 0.0
# [6.800252118106901, 8.297318490270337]
# in sim
# 0.0
# [6.808549436597171, 8.297318490270337]
# in sim
# 0.0
# [6.816846755087441, 8.297318490270337]
# in sim
# 0.0
# [6.825144073577712, 8.297318490270337]
# in sim
# 0.0
# [6.833441392067982, 8.297318490270337]
# in sim
# 0.0
# [6.841738710558253, 8.297318490270337]
# in sim
# 0.0
# [6.850036029048523, 8.297318490270337]
# in sim
# 0.0
# [6.858333347538793, 8.297318490270337]
# in sim
# 0.0
# [6.866630666029064, 8.297318490270337]
# in sim
# 0.0
# [6.874927984519334, 8.297318490270337]
# in sim
# 0.0
# [6.8832253030096044, 8.297318490270337]
# in sim
# 0.0
# [6.891522621499875, 8.297318490270337]
# in sim
# 0.0
# [6.899819939990145, 8.297318490270337]
# in sim
# 0.0
# [6.908117258480416, 8.297318490270337]
# in sim
# 0.0
# [6.916414576970686, 8.297318490270337]
# in sim
# 0.0
# [6.924711895460956, 8.297318490270337]
# in sim
# 0.0
# [6.933009213951227, 8.297318490270337]
# in sim
# 0.0
# [6.941306532441497, 8.297318490270337]
# in sim
# 0.0
# [6.9496038509317675, 8.297318490270337]
# in sim
# 0.0
# [6.957901169422038, 8.297318490270337]
# in sim
# 0.0
# [6.966198487912308, 8.297318490270337]
# in sim
# 0.0
# [6.974495806402579, 8.297318490270337]
# in sim
# 0.0
# [6.982793124892849, 8.297318490270337]
# in sim
# 0.0
# [6.991090443383119, 8.297318490270337]
# in sim
# 0.0
# [6.99938776187339, 8.297318490270337]
# in sim
# 0.0
# [7.00768508036366, 8.297318490270337]
# in sim
# 0.0
# [7.0159823988539305, 8.297318490270337]
# in sim
# 0.0
# [7.024279717344201, 8.297318490270337]
# in sim
# 0.0
# [7.032577035834471, 8.297318490270337]
# in sim
# 0.0
# [7.040874354324742, 8.297318490270337]
# in sim
# 0.0
# [7.049171672815012, 8.297318490270337]
# in sim
# 0.0
# [7.057468991305282, 8.297318490270337]
# in sim
# 0.0
# [7.065766309795553, 8.297318490270337]
# in sim
# 0.0
# [7.074063628285823, 8.297318490270337]
# in sim
# 0.0
# [7.0823609467760935, 8.297318490270337]
# in sim
# 0.0
# [7.090658265266364, 8.297318490270337]
# in sim
# 0.0
# [7.098955583756634, 8.297318490270337]
# in sim
# 0.0
# [7.107252902246905, 8.297318490270337]
# in sim
# 0.0
# [7.115550220737175, 8.297318490270337]
# in sim
# 0.0
# [7.123847539227445, 8.297318490270337]
# in sim
# 0.0
# [7.132144857717716, 8.297318490270337]
# in sim
# 0.0
# [7.140442176207986, 8.297318490270337]
# in sim
# 0.0
# [7.1487394946982565, 8.297318490270337]
# in sim
# 0.0
# [7.157036813188527, 8.297318490270337]
# in sim
# 0.0
# [7.165334131678797, 8.297318490270337]
# in sim
# 0.0
# [7.173631450169068, 8.297318490270337]
# in sim
# 0.0
# [7.181928768659338, 8.297318490270337]
# in sim
# 0.0
# [7.190226087149608, 8.297318490270337]
# in sim
# 0.0
# [7.198523405639879, 8.297318490270337]
# in sim
# 0.0
# [7.206820724130149, 8.297318490270337]
# in sim
# 0.0
# [7.21511804262042, 8.297318490270337]
# in sim
# 0.0
# [7.22341536111069, 8.297318490270337]
# in sim
# 0.0
# [7.23171267960096, 8.297318490270337]
# in sim
# 0.0
# [7.240009998091231, 8.297318490270337]
# in sim
# 0.0
# [7.248307316581501, 8.297318490270337]
# in sim
# 0.0
# [7.2566046350717714, 8.297318490270337]
# in sim
# 0.0
# [7.264901953562042, 8.297318490270337]
# in sim
# 0.0
# [7.273199272052312, 8.297318490270337]
# in sim
# 0.0
# [7.281496590542583, 8.297318490270337]
# in sim
# 0.0
# [7.289793909032853, 8.297318490270337]
# in sim
# 0.0
# [7.298091227523123, 8.297318490270337]
# in sim
# 0.0
# [7.306388546013394, 8.297318490270337]
# in sim
# 0.0
# [7.314685864503664, 8.297318490270337]
# in sim
# 0.0
# [7.3229831829939345, 8.297318490270337]
# in sim
# 0.0
# [7.331280501484205, 8.297318490270337]
# in sim
# 0.0
# [7.339577819974475, 8.297318490270337]
# in sim
# 0.0
# [7.347875138464746, 8.297318490270337]
# in sim
# 0.0
# [7.356172456955016, 8.297318490270337]
# in sim
# 0.0
# [7.364469775445286, 8.297318490270337]
# in sim
# 0.0
# [7.372767093935557, 8.297318490270337]
# in sim
# 0.0
# [7.381064412425827, 8.297318490270337]
# in sim
# 0.0
# [7.3893617309160975, 8.297318490270337]
# in sim
# 0.0
# [7.397659049406368, 8.297318490270337]
# in sim
# 0.0
# [7.405956367896638, 8.297318490270337]
# in sim
# 0.0
# [7.414253686386909, 8.297318490270337]
# in sim
# 0.0
# [7.422551004877179, 8.297318490270337]
# in sim
# 0.0
# [7.430848323367449, 8.297318490270337]
# in sim
# 0.0
# [7.43914564185772, 8.297318490270337]
# in sim
# 0.0
# [7.44744296034799, 8.297318490270337]
# in sim
# 0.0
# [7.4557402788382605, 8.297318490270337]
# in sim
# 0.0
# [7.464037597328531, 8.297318490270337]
# in sim
# 0.0
# [7.472334915818801, 8.297318490270337]
# in sim
# 0.0
# [7.480632234309072, 8.297318490270337]
# in sim
# 0.0
# [7.488929552799342, 8.297318490270337]
# in sim
# 0.0
# [7.497226871289612, 8.297318490270337]
# in sim
# 0.0
# [7.505524189779883, 8.297318490270337]
# in sim
# 0.0
# [7.513821508270153, 8.297318490270337]
# in sim
# 0.0
# [7.5221188267604235, 8.297318490270337]
# in sim
# 0.0
# [7.530416145250694, 8.297318490270337]
# in sim
# 0.0
# [7.538713463740964, 8.297318490270337]
# in sim
# 0.0
# [7.547010782231235, 8.297318490270337]
# in sim
# 0.0
# [7.555308100721505, 8.297318490270337]
# in sim
# 0.0
# [7.563605419211775, 8.297318490270337]
# in sim
# 0.0
# [7.571902737702046, 8.297318490270337]
# in sim
# 0.0
# [7.580200056192316, 8.297318490270337]
# in sim
# 0.0
# [7.588497374682587, 8.297318490270337]
# in sim
# 0.0
# [7.596794693172857, 8.297318490270337]
# in sim
# 0.0
# [7.605092011663127, 8.297318490270337]
# in sim
# 0.0
# [7.613389330153398, 8.297318490270337]
# in sim
# 0.0
# [7.621686648643668, 8.297318490270337]
# in sim
# 0.0
# [7.6299839671339384, 8.297318490270337]
# in sim
# 0.0
# [7.638281285624209, 8.297318490270337]
# in sim
# 0.0
# [7.646578604114479, 8.297318490270337]
# in sim
# 0.0
# [7.65487592260475, 8.297318490270337]
# in sim
# 0.0
# [7.66317324109502, 8.297318490270337]
# in sim
# 0.0
# [7.67147055958529, 8.297318490270337]
# in sim
# 0.0
# [7.679767878075561, 8.297318490270337]
# in sim
# 0.0
# [7.688065196565831, 8.297318490270337]
# in sim
# 0.0
# [7.6963625150561015, 8.297318490270337]
# in sim
# 0.0
# [7.704659833546372, 8.297318490270337]
# in sim
# 0.0
# [7.712957152036642, 8.297318490270337]
# in sim
# 0.0
# [7.721254470526913, 8.297318490270337]
# in sim
# 0.0
# [7.729551789017183, 8.297318490270337]
# in sim
# 0.0
# [7.737849107507453, 8.297318490270337]
# in sim
# 0.0
# [7.746146425997724, 8.297318490270337]
# in sim
# 0.0
# [7.754443744487994, 8.297318490270337]
# in sim
# 0.0
# [7.7627410629782645, 8.297318490270337]
# in sim
# 0.0
# [7.771038381468535, 8.297318490270337]
# in sim
# 0.0
# [7.779335699958805, 8.297318490270337]
# in sim
# 0.0
# [7.787633018449076, 8.297318490270337]
# in sim
# 0.0
# [7.795930336939346, 8.297318490270337]
# in sim
# 0.0
# [7.804227655429616, 8.297318490270337]
# in sim
# 0.0
# [7.812524973919887, 8.297318490270337]
# in sim
# 0.0
# [7.820822292410157, 8.297318490270337]
# in sim
# 0.0
# [7.8291196109004275, 8.297318490270337]
# in sim
# 0.0
# [7.837416929390698, 8.297318490270337]
# in sim
# 0.0
# [7.845714247880968, 8.297318490270337]
# in sim
# 0.0
# [7.854011566371239, 8.297318490270337]
# in sim
# 0.0
# [7.862308884861509, 8.297318490270337]
# in sim
# 0.0
# [7.870606203351779, 8.297318490270337]
# in sim
# 0.0
# [7.87890352184205, 8.297318490270337]
# in sim
# 0.0
# [7.88720084033232, 8.297318490270337]
# in sim
# 0.0
# [7.8954981588225905, 8.297318490270337]
# in sim
# 0.0
# [7.903795477312861, 8.297318490270337]
# in sim
# 0.0
# [7.912092795803131, 8.297318490270337]
# in sim
# 0.0
# [7.920390114293402, 8.297318490270337]
# in sim
# 0.0
# [7.928687432783672, 8.297318490270337]
# in sim
# 0.0
# [7.936984751273942, 8.297318490270337]
# in sim
# 0.0
# [7.945282069764213, 8.297318490270337]
# in sim
# 0.0
# [7.953579388254483, 8.297318490270337]
# in sim
# 0.0
# [7.961876706744754, 8.297318490270337]
# in sim
# 0.0
# [7.970174025235024, 8.297318490270337]
# in sim
# 0.0
# [7.978471343725294, 8.297318490270337]
# in sim
# 0.0
# [7.986768662215565, 8.297318490270337]
# in sim
# 0.0
# [7.995065980705835, 8.297318490270337]
# in sim
# 0.0
# [8.003363299196105, 8.297318490270337]
# in sim
# 0.0
# [8.011660617686374, 8.297318490270337]
# in sim
# 0.0
# [8.019957936176644, 8.297318490270337]
# in sim
# 0.0
# [8.028255254666913, 8.297318490270337]
# in sim
# 0.0
# [8.036552573157183, 8.297318490270337]
# in sim
# 0.0
# [8.044849891647452, 8.297318490270337]
# in sim
# 0.0
# [8.053147210137722, 8.297318490270337]
# in sim
# 0.0
# [8.061444528627991, 8.297318490270337]
# in sim
# 0.0
# [8.06974184711826, 8.297318490270337]
# in sim
# 0.0
# [8.07803916560853, 8.297318490270337]
# in sim
# 0.0
# [8.0863364840988, 8.297318490270337]
# in sim
# 0.0
# [8.094633802589069, 8.297318490270337]

# %%
anim = plot_stick(theta_hist, ts, params)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Q.3.(b) [5 pts] What is the angular position and velocity after 0.5, 1.0, 1.5 sec?

# %%
# Fill your code: Print the angular position and velocity of the arm @ 1, 2, 3 sec
...
# Out:
# 1 sec pos: 0.3962334159211724, vel: 0.8332971897656587
# 2 sec pos: 0.8128820108040016, vel: 0.8332971897656587
# 3 sec pos: 1.2295306056868613, vel: 0.8332971897656587

# %% [markdown]
# ## Q.3. (c) [15 pts] Compute the torque to hold the position of the stick when $F = 50$N at the three following position ($\dot{\theta} = 0$)
# ### (i) $\theta=0$, $\theta=\frac{\pi}{4}$, and $\theta=\frac{\pi}{6}$
# ### (ii) Simulate the robot at the configuration in (i) and check whether the stick moves or not.

# %%
_, _, _, l, _, _ = params

# Fill your code: Compute the torque to hold the motion of the arm
...
# Out:
# Torque: -50.00 Nm
# Torque: -35.36 Nm
# Torque: -43.30 Nm

# %%
# Test your torque: The arm should not move
[theta_hist, theta_dot_hist, ts] = simulate_stick(theta=theta, theta_dot=0, F=50, tau=tau, F_duration=1.0, F_start_time=0.0, T=1.0, params=params)
anim = plot_stick(theta_hist, ts, params)
plt.close()
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
